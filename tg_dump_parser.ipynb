# %%
import json
from pathlib import Path
from typing import Dict, Any, List, Optional, Set

import typer
import pandas as pd


Message = {}
Context = []



def prepare_messages(tg_history_path, output_path,):
    with open(tg_history_path) as messages_file:
        messages = json.load(messages_file)['messages']

    contexts = _create_contexts(messages)
    contexts = _transform_contexts(contexts)

    contexts_df = pd.DataFrame.from_records(contexts)
    contexts_df.drop_duplicates(inplace=True)
    contexts_df.to_csv(output_path, index=False)


def _create_contexts(messages):
    replies_threads = {}
    id_to_message = {}
    for message in messages:
        id_to_message[message['id']] = message
        if 'reply_to_message_id' in message:
            replies_threads[message['reply_to_message_id']] = message['id']

    contexts = []
    cur_context = _create_default_list()
    visited_replies = set()

    for message in messages:
        if (
            message['type'] != 'message' or
            not message['text'] or
            not isinstance(message['text'], str) or
            message['id'] in visited_replies
        ):
            continue

        if 'forwarded_from' in message and cur_context:
            contexts.append(cur_context)
            cur_context = _create_default_list()
            continue

        if message['id'] in replies_threads:
            contexts.append(cur_context)
            cur_context = _create_default_list()
            _resolve_thread(contexts, replies_threads, visited_replies, id_to_message, message)
            continue

        if cur_context[-1] and message['from_id'] == cur_context[-1]['from_id']:
            contexts[-1][-1]['text'] += '\n' + message["text"]
            continue

        cur_context.pop(0)
        cur_context.append(message)
        contexts.append(cur_context.copy())

    return contexts


def _resolve_thread(
    contexts,
    replies_threads,
    visited_replies,
    id_to_message,
    message,
) -> None:
    cur_context = _create_default_list()
    cur_id = message['id']

    while cur_id:
        cur_context.pop(0)
        cur_context.append(id_to_message[cur_id])
        contexts.append(cur_context.copy())

        visited_replies.add(cur_id)
        cur_id = replies_threads.get(cur_id)


def _transform_contexts(contexts):
    return [_transform_context(context) for context in contexts if any(context)]


def _transform_context(context):
    return {
        'context_3': _transform_message(context[0]),
        'context_2': _transform_message(context[1]),
        'context_1': _transform_message(context[2]),
        'response': _transform_message(context[3]),
    }


def _transform_message(message):
    if not message:
        return None

    if isinstance(message['text'], list):
        texts = [text['text'] if isinstance(text, dict) else text for text in message['text']]
        message['text'] = ''.join(texts)

    return message['text']


def _create_default_list(message = ''):
    return [None, None, None, message]

# %%
with open(tg_history_path) as messages_file:
        messages = json.load(messages_file)['messages']

# %%
bool('s')
# Out:
# True

# %%
messages[7]
# Out:
# {'id': 115,
#  'type': 'message',
#  'date': '2023-03-01T12:44:03',
#  'date_unixtime': '1677663843',
#  'from': 'Аня ❤️',
#  'from_id': 'user348973081',
#  'forwarded_from': 'Аня ❤️',
#  'text': '5. Какой наиболее часто мутирующий ген при раке? Какая у него функция?\n*',
#  'text_entities': [{'type': 'plain',
#    'text': '5. Какой наиболее часто мутирующий ген при раке? Какая у него функция?\n*'}]}

# %%
messages[-95]
# Out:
# {'id': 17273,
#  'type': 'message',
#  'date': '2023-08-24T08:05:19',
#  'date_unixtime': '1692853519',
#  'from': 'Мама',
#  'from_id': 'user5070028513',
#  'text': 'Я блины с мясом и кофе с молоком беру',
#  'text_entities': [{'type': 'plain',
#    'text': 'Я блины с мясом и кофе с молоком беру'}]}

# %%
messages[-92]
# Out:
# {'id': 17281,
#  'type': 'message',
#  'date': '2023-08-24T11:47:08',
#  'date_unixtime': '1692866828',
#  'from': 'No',
#  'from_id': 'user5982387868',
#  'text': 'Мы прилетели',
#  'text_entities': [{'type': 'plain', 'text': 'Мы прилетели'}]}

# %%
messages[-93]
# Out:
# {'id': 17275,
#  'type': 'message',
#  'date': '2023-08-24T08:05:27',
#  'date_unixtime': '1692853527',
#  'from': 'No',
#  'from_id': 'user5982387868',
#  'reply_to_message_id': 17273,
#  'text': 'Ну или так',
#  'text_entities': [{'type': 'plain', 'text': 'Ну или так'}]}

# %%
messages[-100]
# Out:
# {'id': 17239,
#  'type': 'message',
#  'date': '2023-08-24T07:12:35',
#  'date_unixtime': '1692850355',
#  'from': 'Мама',
#  'from_id': 'user5070028513',
#  'file': '(File not included. Change data exporting settings to download.)',
#  'thumbnail': '(File not included. Change data exporting settings to download.)',
#  'media_type': 'sticker',
#  'sticker_emoji': '😘',
#  'width': 512,
#  'height': 512,
#  'text': '',
#  'text_entities': []}

# %%
messages[83]
# Out:
# {'id': 194,
#  'type': 'message',
#  'date': '2023-03-13T13:12:06',
#  'date_unixtime': '1678702326',
#  'from': 'No',
#  'from_id': 'user5982387868',
#  'text': 'на 6 точно напишу',
#  'text_entities': [{'type': 'plain', 'text': 'на 6 точно напишу'}]}

# %%
import re 

st = '''['Watch "Как отсрочить старость? Рассказывает эндокринолог" on YouTube\n', {'type': 'link', 'text': 'https://youtu.be/imgZSjmO4BY'}, '']'''
print(re.search("(?P<url>https?://[^\s]+)", st))
# Out:
# <re.Match object; span=(100, 131), match="https://youtu.be/imgZSjmO4BY'},">

# %%
len('''нтерес к машинному обучению у меня появился, когда я узнала про NLP. 
Сначала я училась на экономике и выбрала в качестве майнора ИАД, но мне хотелось больше погрузиться в Computer Science, поэтому я перепоступила на ПМИ в конце 1 курса. В марте я была на Школе искусственного Интеллекта МТС. Там я посетила лекцию Сергея Загоруйко, где он рассказывал о своей карьере и задачах, которые он решал: 3D реконструкция, детекция объектов, беспилотные автомобили; а также о том, как развивались эти области последние 10 лет. Его рассказ очень меня впечатлил. Мне нравится, что в машинном обучении есть много интересных направлений,которые позволяют решать большое количество задач на стыке разных областей. Мне было бы интересно в будущем поработать в нескольких сферах: обработке естественного языка, биоинформатике, чем-то, связанном с компьютерным зрением. На МОПе есть курсы по выбору по всем этим темам, где я смогу получше узнать каждую из них и понять, что мне ближе
Аня ❤️:переписала кусок мотивашки посмотри пожалуйста🥺🥺🥺''')
# Out:
# 1024

# %%
# from datetime import datetime, timedelta
# import json

# def process_chat(chat_data):
#     # Сортировка сообщений по дате
#     sorted_chat = sorted(chat_data, key=lambda x: x['date_unixtime'])

#     dialogs = []
#     current_dialog = ['']
#     prev_time = None

#     for message in sorted_chat:
#         if message['from'] == 'No':
#             # Преобразование даты из строки в объект datetime
#             message_time = datetime.strptime(message['date'], '%Y-%m-%dT%H:%M:%S')

#             if prev_time is None or (message_time - prev_time) <= timedelta(hours=2):
#                 current_dialog.append(message['text'])
#             else:
#                 if current_dialog:
#                     dialogs.append(' '.join(current_dialog))
#                 current_dialog = [message['text']]

#             prev_time = message_time

#     if current_dialog:
#         dialogs.append(' '.join(current_dialog))

#     return dialogs

# # Пример входных данных
# input_data = [
#     # ... (ваш входной json здесь)
# ]

# dialogs = process_chat(messages)

# for i, dialog in enumerate(dialogs, start=1):
#     print(f"Dialog {i}: {dialog}\n")

# %%
messages
# Out:
# [{'id': 101,
#   'type': 'message',
#   'date': '2023-02-16T18:32:17',
#   'date_unixtime': '1676561537',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'Никит?',
#   'text_entities': [{'type': 'plain', 'text': 'Никит?'}]},
#  {'id': 102,
#   'type': 'message',
#   'date': '2023-02-20T22:12:28',
#   'date_unixtime': '1676920348',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'forwarded_from': 'Other',
#   'text': 'Почему я хочу попасть на школу по ИИ от МТС?\n\nИИ я начал увлекаться еще в школе, тогда я смотрел популярные лекции малого ШАДа и выступления Андрея Сербанта, потом я решил изучать программирование на си, в вузе освоил питон, прошел курсы по теорверу и матстату от CSC, в сентябре начал заниматься продуктовой аналитикой, прошел курс от Тинькофф, но потом понял, что на продуктовой аналитике я останавливаться не хочу, мне захотелось двигаться в более техническую сферу и для меня очевидным выбор был DS, я прошел отбор на курс Тинькофф по ML, параллельно изучая курс по ML от  Радослава Нейчева на ФПМИ МФТИ. Сейчас я завершаю курсы по ML, и считаю, что самое время начать осваивать DL, в чем собственно и вижу цель поступления в школу по ИИ от МТС\n\nОтдельно стоит упомянуть мое отношение к самой компании. До недавнего времени я почти не слышал про МТС, пока не подписался на блог нескольких людей из компании, не пообщался с людьми, проходившими обучения на курсах от МТС. Могу сказать, что сейчас я смотрю на МТС, как на очень перспективную компанию, активно развивающую множество новых направлений, и возможно, будущего работодателя.',
#   'text_entities': [{'type': 'plain',
#     'text': 'Почему я хочу попасть на школу по ИИ от МТС?\n\nИИ я начал увлекаться еще в школе, тогда я смотрел популярные лекции малого ШАДа и выступления Андрея Сербанта, потом я решил изучать программирование на си, в вузе освоил питон, прошел курсы по теорверу и матстату от CSC, в сентябре начал заниматься продуктовой аналитикой, прошел курс от Тинькофф, но потом понял, что на продуктовой аналитике я останавливаться не хочу, мне захотелось двигаться в более техническую сферу и для меня очевидным выбор был DS, я прошел отбор на курс Тинькофф по ML, параллельно изучая курс по ML от  Радослава Нейчева на ФПМИ МФТИ. Сейчас я завершаю курсы по ML, и считаю, что самое время начать осваивать DL, в чем собственно и вижу цель поступления в школу по ИИ от МТС\n\nОтдельно стоит упомянуть мое отношение к самой компании. До недавнего времени я почти не слышал про МТС, пока не подписался на блог нескольких людей из компании, не пообщался с людьми, проходившими обучения на курсах от МТС. Могу сказать, что сейчас я смотрю на МТС, как на очень перспективную компанию, активно развивающую множество новых направлений, и возможно, будущего работодателя.'}]},
#  {'id': 103,
#   'type': 'message',
#   'date': '2023-02-20T22:13:35',
#   'date_unixtime': '1676920415',
#   'edited': '2023-02-20T22:42:29',
#   'edited_unixtime': '1676922149',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'Давно интересуюсь машинным обучением и возможностями его применения в разных областях, особенно в обработке естественного языка. Кроме того, обучаюсь на майноре по биоинформатике, где тоже со временем появится машинное обучение, а также хочу весной попасть на специализацию по машинному обучению. Летом у меня уже была практика на kaggle в задаче классификации (определение человека по фотографии), однако мало времени уделялось теории, поэтому очень интересно узнать, как же работают методы и подходы, которые я применяла. Курс даст мне шанс убедиться, что я иду на подходящую для себя специализацию, а также поможет в подготовке к летней стажировке, которую я хочу связать с данной областью и, возможно, с компанией МТС',
#   'text_entities': [{'type': 'plain',
#     'text': 'Давно интересуюсь машинным обучением и возможностями его применения в разных областях, особенно в обработке естественного языка. Кроме того, обучаюсь на майноре по биоинформатике, где тоже со временем появится машинное обучение, а также хочу весной попасть на специализацию по машинному обучению. Летом у меня уже была практика на kaggle в задаче классификации (определение человека по фотографии), однако мало времени уделялось теории, поэтому очень интересно узнать, как же работают методы и подходы, которые я применяла. Курс даст мне шанс убедиться, что я иду на подходящую для себя специализацию, а также поможет в подготовке к летней стажировке, которую я хочу связать с данной областью и, возможно, с компанией МТС'}]},
#  {'id': 104,
#   'type': 'message',
#   'date': '2023-02-20T22:53:05',
#   'date_unixtime': '1676922785',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'Курс даст мне возможность погрузиться в актуальные темы в DL, побывать на лекциях специалистов в этой области, а также узнать больше про компанию МТС, которую я рассматриваю как отличный вариант для летней стажировки',
#   'text_entities': [{'type': 'plain',
#     'text': 'Курс даст мне возможность погрузиться в актуальные темы в DL, побывать на лекциях специалистов в этой области, а также узнать больше про компанию МТС, которую я рассматриваю как отличный вариант для летней стажировки'}]},
#  {'id': 105,
#   'type': 'message',
#   'date': '2023-02-20T22:56:35',
#   'date_unixtime': '1676922995',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'Давно интересуюсь машинным обучением и возможностями его применения в разных областях, особенно в обработке естественного языка. В прошлом году я прошла на летнюю школу ML and Texts. Кроме того, обучаюсь на майноре по биоинформатике, в задачах которой применяется машинное обучение, а также хочу весной попасть на специализацию по машинному обучению. Летом у меня уже была практика на kaggle в задаче классификации (определение человека по фотографии). Курс даст мне возможность погрузиться в актуальные темы в ИИ, побывать на лекциях специалистов в этой области, а также узнать больше про компанию МТС, которую я рассматриваю как отличный вариант для летней стажировки',
#   'text_entities': [{'type': 'plain',
#     'text': 'Давно интересуюсь машинным обучением и возможностями его применения в разных областях, особенно в обработке естественного языка. В прошлом году я прошла на летнюю школу ML and Texts. Кроме того, обучаюсь на майноре по биоинформатике, в задачах которой применяется машинное обучение, а также хочу весной попасть на специализацию по машинному обучению. Летом у меня уже была практика на kaggle в задаче классификации (определение человека по фотографии). Курс даст мне возможность погрузиться в актуальные темы в ИИ, побывать на лекциях специалистов в этой области, а также узнать больше про компанию МТС, которую я рассматриваю как отличный вариант для летней стажировки'}]},
#  {'id': 111,
#   'type': 'message',
#   'date': '2023-02-27T22:33:22',
#   'date_unixtime': '1677526402',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': [{'type': 'link',
#     'text': 'https://docviewer.yandex.ru/view/1049160442/?page=3&*=3Z%%3D'}],
#   'text_entities': [{'type': 'link',
#     'text': 'https://docviewer.yandex.ru/view/1049160442/?page=3&*=3Z%%3D'}]},
#  {'id': 114,
#   'type': 'message',
#   'date': '2023-03-01T12:42:42',
#   'date_unixtime': '1677663762',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'g',
#   'text_entities': [{'type': 'plain', 'text': 'g'}]},
#  {'id': 115,
#   'type': 'message',
#   'date': '2023-03-01T12:44:03',
#   'date_unixtime': '1677663843',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'forwarded_from': 'Аня ❤️',
#   'text': '5. Какой наиболее часто мутирующий ген при раке? Какая у него функция?\n*',
#   'text_entities': [{'type': 'plain',
#     'text': '5. Какой наиболее часто мутирующий ген при раке? Какая у него функция?\n*'}]},
#  {'id': 116,
#   'type': 'message',
#   'date': '2023-03-01T12:44:32',
#   'date_unixtime': '1677663872',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'Могут ли разные мутации в геноме приводить к одному и тому же фенотипу рака? (да/нет)',
#   'text_entities': [{'type': 'plain',
#     'text': 'Могут ли разные мутации в геноме приводить к одному и тому же фенотипу рака? (да/нет)'}]},
#  {'id': 117,
#   'type': 'message',
#   'date': '2023-03-01T12:44:59',
#   'date_unixtime': '1677663899',
#   'edited': '2023-03-01T12:45:14',
#   'edited_unixtime': '1677663914',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'Существует множество генов, которые мутируют при раке, и нет одного конкретного гена, который мутирует чаще всего. Это зависит от типа рака и индивидуальных характеристик опухоли у каждого пациента.\n\nОднако, некоторые из самых часто мутирующих генов, связанных с различными типами рака, включают:\n\nTP53 - этот ген кодирует белок, который регулирует цикл клеточного деления и предотвращает развитие рака. Мутации TP53 обнаруживаются у большинства типов рака.\n\nKRAS - этот ген кодирует белок, который помогает регулировать рост и деление клеток. Мутации KRAS обнаруживаются у многих видов рака, включая легочный, толстой кишки, поджелудочной железы и другие.\n\nBRAF - этот ген кодирует белок, который также помогает регулировать рост и деление клеток. Мутации BRAF обнаруживаются у различных типов рака, включая меланому, тиреоидный и другие.\n\nделения клеток. Мутации EGFR обнаруживаются у различных типов рака, включая легочный, мозговой и другие.\n\nФункции этих генов различны, но все они играют важную роль в регуляции роста и деления клеток, что делает их ключевыми мишенями для терапии рака.',
#   'text_entities': [{'type': 'plain',
#     'text': 'Существует множество генов, которые мутируют при раке, и нет одного конкретного гена, который мутирует чаще всего. Это зависит от типа рака и индивидуальных характеристик опухоли у каждого пациента.\n\nОднако, некоторые из самых часто мутирующих генов, связанных с различными типами рака, включают:\n\nTP53 - этот ген кодирует белок, который регулирует цикл клеточного деления и предотвращает развитие рака. Мутации TP53 обнаруживаются у большинства типов рака.\n\nKRAS - этот ген кодирует белок, который помогает регулировать рост и деление клеток. Мутации KRAS обнаруживаются у многих видов рака, включая легочный, толстой кишки, поджелудочной железы и другие.\n\nBRAF - этот ген кодирует белок, который также помогает регулировать рост и деление клеток. Мутации BRAF обнаруживаются у различных типов рака, включая меланому, тиреоидный и другие.\n\nделения клеток. Мутации EGFR обнаруживаются у различных типов рака, включая легочный, мозговой и другие.\n\nФункции этих генов различны, но все они играют важную роль в регуляции роста и деления клеток, что делает их ключевыми мишенями для терапии рака.'}]},
#  {'id': 118,
#   'type': 'message',
#   'date': '2023-03-01T12:45:37',
#   'date_unixtime': '1677663937',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'Могут ли разные мутации в геноме приводить к одному и тому же фенотипу рака? (да/нет)',
#   'text_entities': [{'type': 'plain',
#     'text': 'Могут ли разные мутации в геноме приводить к одному и тому же фенотипу рака? (да/нет)'}]},
#  {'id': 119,
#   'type': 'message',
#   'date': '2023-03-01T12:45:50',
#   'date_unixtime': '1677663950',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'да',
#   'text_entities': [{'type': 'plain', 'text': 'да'}]},
#  {'id': 120,
#   'type': 'message',
#   'date': '2023-03-01T12:45:59',
#   'date_unixtime': '1677663959',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'Что такое ген-супрессор?  Что он делает в норме и при раке?\n*',
#   'text_entities': [{'type': 'plain',
#     'text': 'Что такое ген-супрессор?  Что он делает в норме и при раке?\n*'}]},
#  {'id': 121,
#   'type': 'message',
#   'date': '2023-03-01T12:46:05',
#   'date_unixtime': '1677663965',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'Что такое онкоген? Что он делает в норме и при раке?',
#   'text_entities': [{'type': 'plain',
#     'text': 'Что такое онкоген? Что он делает в норме и при раке?'}]},
#  {'id': 122,
#   'type': 'message',
#   'date': '2023-03-01T12:47:34',
#   'date_unixtime': '1677664054',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'Ген-супрессор - это ген, который кодирует белок, который обычно подавляет рост и деление клеток в организме. Он играет важную роль в поддержании нормальной клеточной дифференциации, а также предотвращает развитие рака.\n\nВ норме, ген-супрессоры регулируют клеточный цикл и устраняют клетки, которые имеют поврежденный ДНК, препятствуя их превращению в раковые клетки. Они также контролируют процессы апоптоза (программированной клеточной смерти), которые устраняют клетки, которые потенциально могут стать опухолевыми.\n\nВ случае мутации ген-супрессора, белок, который он кодирует, может стать неактивным или потерять свою функцию. Это может привести к неправильной регуляции клеточного цикла и стимулированию ненормального роста и деления клеток, что может привести к развитию рака. Мутации генов-супрессоров могут быть унаследованными, но они также могут возникать в результате накопления мутаций в клетках в процессе жизненного цикла организма или под воздействием окружающей среды, такой как курение, излучение и другие канцерогенные факторы.\n\nПримеры генов-супрессоров включают TP53, BRCA1, BRCA2, PTEN и другие. Их мутации связаны с различными видами рака, включая рак молочной железы, рак яичников, рак простаты, рак толстой кишки и другие.',
#   'text_entities': [{'type': 'plain',
#     'text': 'Ген-супрессор - это ген, который кодирует белок, который обычно подавляет рост и деление клеток в организме. Он играет важную роль в поддержании нормальной клеточной дифференциации, а также предотвращает развитие рака.\n\nВ норме, ген-супрессоры регулируют клеточный цикл и устраняют клетки, которые имеют поврежденный ДНК, препятствуя их превращению в раковые клетки. Они также контролируют процессы апоптоза (программированной клеточной смерти), которые устраняют клетки, которые потенциально могут стать опухолевыми.\n\nВ случае мутации ген-супрессора, белок, который он кодирует, может стать неактивным или потерять свою функцию. Это может привести к неправильной регуляции клеточного цикла и стимулированию ненормального роста и деления клеток, что может привести к развитию рака. Мутации генов-супрессоров могут быть унаследованными, но они также могут возникать в результате накопления мутаций в клетках в процессе жизненного цикла организма или под воздействием окружающей среды, такой как курение, излучение и другие канцерогенные факторы.\n\nПримеры генов-супрессоров включают TP53, BRCA1, BRCA2, PTEN и другие. Их мутации связаны с различными видами рака, включая рак молочной железы, рак яичников, рак простаты, рак толстой кишки и другие.'}]},
#  {'id': 123,
#   'type': 'message',
#   'date': '2023-03-01T12:47:43',
#   'date_unixtime': '1677664063',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'Что такое ген-драйвер?',
#   'text_entities': [{'type': 'plain', 'text': 'Что такое ген-драйвер?'}]},
#  {'id': 124,
#   'type': 'message',
#   'date': '2023-03-01T12:47:48',
#   'date_unixtime': '1677664068',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'Что такое ген-пассажир?',
#   'text_entities': [{'type': 'plain', 'text': 'Что такое ген-пассажир?'}]},
#  {'id': 125,
#   'type': 'message',
#   'date': '2023-03-01T12:48:36',
#   'date_unixtime': '1677664116',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'Онкоген - это ген, который кодирует белок, который может способствовать ненормальному росту и размножению клет',
#   'text_entities': [{'type': 'plain',
#     'text': 'Онкоген - это ген, который кодирует белок, который может способствовать ненормальному росту и размножению клет'}]},
#  {'id': 126,
#   'type': 'message',
#   'date': '2023-03-01T12:49:43',
#   'date_unixtime': '1677664183',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'Ген-драйвер (gene driver) - это генетический элемент, который приводит к высокой частоте передачи своей копии наследственной информации от одного поколения к другому.',
#   'text_entities': [{'type': 'plain',
#     'text': 'Ген-драйвер (gene driver) - это генетический элемент, который приводит к высокой частоте передачи своей копии наследственной информации от одного поколения к другому.'}]},
#  {'id': 127,
#   'type': 'message',
#   'date': '2023-03-01T17:48:05',
#   'date_unixtime': '1677682085',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': [{'type': 'link',
#     'text': 'https://alexanderdyakonov.wordpress.com/2019/10/31/%D0%BB%D0%B8%D0%BD%D0%B5%D0%B9%D0%BD%D0%B0%D1%8F-%D1%80%D0%B5%D0%B3%D1%80%D0%B5%D1%81%D1%81%D0%B8%D1%8F/comment-page-1/'}],
#   'text_entities': [{'type': 'link',
#     'text': 'https://alexanderdyakonov.wordpress.com/2019/10/31/%D0%BB%D0%B8%D0%BD%D0%B5%D0%B9%D0%BD%D0%B0%D1%8F-%D1%80%D0%B5%D0%B3%D1%80%D0%B5%D1%81%D1%81%D0%B8%D1%8F/comment-page-1/'}]},
#  {'id': 128,
#   'type': 'message',
#   'date': '2023-03-01T22:37:15',
#   'date_unixtime': '1677699435',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'Вы хде',
#   'text_entities': [{'type': 'plain', 'text': 'Вы хде'}]},
#  {'id': 129,
#   'type': 'message',
#   'date': '2023-03-01T23:54:26',
#   'date_unixtime': '1677704066',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'forwarded_from': 'Аня ❤️',
#   'text': 'plotly.offline.init_notebook_mode()',
#   'text_entities': [{'type': 'plain',
#     'text': 'plotly.offline.init_notebook_mode()'}]},
#  {'id': 130,
#   'type': 'message',
#   'date': '2023-03-02T18:05:15',
#   'date_unixtime': '1677769515',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'Если вы туть, то можете кинуть ту ссылку, которую я вам скинул',
#   'text_entities': [{'type': 'plain',
#     'text': 'Если вы туть, то можете кинуть ту ссылку, которую я вам скинул'}]},
#  {'id': 131,
#   'type': 'message',
#   'date': '2023-03-02T18:05:25',
#   'date_unixtime': '1677769525',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'а то я сейчас записываю на телефон и он занят',
#   'text_entities': [{'type': 'plain',
#     'text': 'а то я сейчас записываю на телефон и он занят'}]},
#  {'id': 132,
#   'type': 'message',
#   'date': '2023-03-02T18:05:32',
#   'date_unixtime': '1677769532',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'а мне самому тоже надо отметиться)',
#   'text_entities': [{'type': 'plain',
#     'text': 'а мне самому тоже надо отметиться)'}]},
#  {'id': 133,
#   'type': 'message',
#   'date': '2023-03-02T18:05:48',
#   'date_unixtime': '1677769548',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': [{'type': 'link',
#     'text': 'https://forms.yandex.ru/u/63fc70ebf47e73183e621d58/'}],
#   'text_entities': [{'type': 'link',
#     'text': 'https://forms.yandex.ru/u/63fc70ebf47e73183e621d58/'}]},
#  {'id': 134,
#   'type': 'message',
#   'date': '2023-03-02T18:05:52',
#   'date_unixtime': '1677769552',
#   'edited': '2023-03-02T18:05:55',
#   'edited_unixtime': '1677769555',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'спасибо',
#   'text_entities': [{'type': 'plain', 'text': 'спасибо'}]},
#  {'id': 135,
#   'type': 'message',
#   'date': '2023-03-02T18:05:57',
#   'date_unixtime': '1677769557',
#   'edited': '2023-03-02T18:06:01',
#   'edited_unixtime': '1677769561',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'вам лекцию записываю',
#   'text_entities': [{'type': 'plain', 'text': 'вам лекцию записываю'}]},
#  {'id': 136,
#   'type': 'message',
#   'date': '2023-03-02T18:05:58',
#   'date_unixtime': '1677769558',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'разрешили',
#   'text_entities': [{'type': 'plain', 'text': 'разрешили'}]},
#  {'id': 137,
#   'type': 'message',
#   'date': '2023-03-02T18:06:00',
#   'date_unixtime': '1677769560',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'прям видео',
#   'text_entities': [{'type': 'plain', 'text': 'прям видео'}]},
#  {'id': 138,
#   'type': 'message',
#   'date': '2023-03-02T18:06:09',
#   'date_unixtime': '1677769569',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'А я отметилась…',
#   'text_entities': [{'type': 'plain', 'text': 'А я отметилась…'}]},
#  {'id': 139,
#   'type': 'message',
#   'date': '2023-03-02T18:06:11',
#   'date_unixtime': '1677769571',
#   'edited': '2023-03-02T18:06:14',
#   'edited_unixtime': '1677769574',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'Норм же?',
#   'text_entities': [{'type': 'plain', 'text': 'Норм же?'}]},
#  {'id': 140,
#   'type': 'message',
#   'date': '2023-03-02T18:06:20',
#   'date_unixtime': '1677769580',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'да',
#   'text_entities': [{'type': 'plain', 'text': 'да'}]},
#  {'id': 141,
#   'type': 'message',
#   'date': '2023-03-02T18:06:27',
#   'date_unixtime': '1677769587',
#   'edited': '2023-03-02T18:08:13',
#   'edited_unixtime': '1677769693',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'так и надо, отмечайся)',
#   'text_entities': [{'type': 'plain', 'text': 'так и надо, отмечайся)'}]},
#  {'id': 142,
#   'type': 'message',
#   'date': '2023-03-02T18:08:22',
#   'date_unixtime': '1677769702',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'forwarded_from': 'Аня ❤️',
#   'photo': '(File not included. Change data exporting settings to download.)',
#   'width': 1280,
#   'height': 960,
#   'text': 'Добрый день, заболела вчера, сегодня положительный тест на коронавирус пришел, температура весь день. Возможно ли подвинуть дедлайн по оценке за семинары на один-два дня?',
#   'text_entities': [{'type': 'plain',
#     'text': 'Добрый день, заболела вчера, сегодня положительный тест на коронавирус пришел, температура весь день. Возможно ли подвинуть дедлайн по оценке за семинары на один-два дня?'}]},
#  {'id': 143,
#   'type': 'message',
#   'date': '2023-03-02T18:08:29',
#   'date_unixtime': '1677769709',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'Гут?',
#   'text_entities': [{'type': 'plain', 'text': 'Гут?'}]},
#  {'id': 145,
#   'type': 'message',
#   'date': '2023-03-04T00:13:36',
#   'date_unixtime': '1677878016',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': [{'type': 'link',
#     'text': 'https://teach-in.ru/course/little-mehmat-9-11'}],
#   'text_entities': [{'type': 'link',
#     'text': 'https://teach-in.ru/course/little-mehmat-9-11'}]},
#  {'id': 146,
#   'type': 'message',
#   'date': '2023-03-04T00:21:49',
#   'date_unixtime': '1677878509',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': [{'type': 'link',
#     'text': 'https://fintech.tinkoff.ru/school/generation/math/'}],
#   'text_entities': [{'type': 'link',
#     'text': 'https://fintech.tinkoff.ru/school/generation/math/'}]},
#  {'id': 147,
#   'type': 'message',
#   'date': '2023-03-04T00:22:14',
#   'date_unixtime': '1677878534',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': [{'type': 'link', 'text': 'https://appdatascience.github.io/'}],
#   'text_entities': [{'type': 'link',
#     'text': 'https://appdatascience.github.io/'}]},
#  {'id': 148,
#   'type': 'message',
#   'date': '2023-03-04T00:22:32',
#   'date_unixtime': '1677878552',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': [{'type': 'link', 'text': 'https://appdatascience.github.io/'}],
#   'text_entities': [{'type': 'link',
#     'text': 'https://appdatascience.github.io/'}]},
#  {'id': 150,
#   'type': 'message',
#   'date': '2023-03-06T14:10:20',
#   'date_unixtime': '1678101020',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'photo': '(File not included. Change data exporting settings to download.)',
#   'width': 919,
#   'height': 490,
#   'text': '',
#   'text_entities': []},
#  {'id': 151,
#   'type': 'message',
#   'date': '2023-03-06T14:10:37',
#   'date_unixtime': '1678101037',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'у вас по этой теме эссе было на правовой грамотности?',
#   'text_entities': [{'type': 'plain',
#     'text': 'у вас по этой теме эссе было на правовой грамотности?'}]},
#  {'id': 152,
#   'type': 'message',
#   'date': '2023-03-06T14:11:38',
#   'date_unixtime': '1678101098',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'jq',
#   'text_entities': [{'type': 'plain', 'text': 'jq'}]},
#  {'id': 153,
#   'type': 'message',
#   'date': '2023-03-06T14:11:39',
#   'date_unixtime': '1678101099',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'ой',
#   'text_entities': [{'type': 'plain', 'text': 'ой'}]},
#  {'id': 154,
#   'type': 'message',
#   'date': '2023-03-06T14:11:41',
#   'date_unixtime': '1678101101',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'там нет темы',
#   'text_entities': [{'type': 'plain', 'text': 'там нет темы'}]},
#  {'id': 155,
#   'type': 'message',
#   'date': '2023-03-06T14:11:42',
#   'date_unixtime': '1678101102',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'сча',
#   'text_entities': [{'type': 'plain', 'text': 'сча'}]},
#  {'id': 156,
#   'type': 'message',
#   'date': '2023-03-06T14:11:50',
#   'date_unixtime': '1678101110',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'У нас было по произвольной',
#   'text_entities': [{'type': 'plain', 'text': 'У нас было по произвольной'}]},
#  {'id': 157,
#   'type': 'message',
#   'date': '2023-03-06T14:12:00',
#   'date_unixtime': '1678101120',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'Могу помочь с ним',
#   'text_entities': [{'type': 'plain', 'text': 'Могу помочь с ним'}]},
#  {'id': 158,
#   'type': 'message',
#   'date': '2023-03-06T14:12:21',
#   'date_unixtime': '1678101141',
#   'edited': '2023-03-06T14:12:24',
#   'edited_unixtime': '1678101144',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'Буду минут через 10',
#   'text_entities': [{'type': 'plain', 'text': 'Буду минут через 10'}]},
#  {'id': 159,
#   'type': 'message',
#   'date': '2023-03-06T14:12:32',
#   'date_unixtime': '1678101152',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'оки',
#   'text_entities': [{'type': 'plain', 'text': 'оки'}]},
#  {'id': 160,
#   'type': 'message',
#   'date': '2023-03-06T14:13:03',
#   'date_unixtime': '1678101183',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'photo': '(File not included. Change data exporting settings to download.)',
#   'width': 1280,
#   'height': 486,
#   'text': '',
#   'text_entities': []},
#  {'id': 161,
#   'type': 'message',
#   'date': '2023-03-06T14:13:07',
#   'date_unixtime': '1678101187',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'я могу ваше эссе взять)?',
#   'text_entities': [{'type': 'plain', 'text': 'я могу ваше эссе взять)?'}]},
#  {'id': 162,
#   'type': 'message',
#   'date': '2023-03-06T14:22:22',
#   'date_unixtime': '1678101742',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'reply_to_message_id': 161,
#   'text': 'Обсудим за едой)',
#   'text_entities': [{'type': 'plain', 'text': 'Обсудим за едой)'}]},
#  {'id': 163,
#   'type': 'message',
#   'date': '2023-03-07T00:36:45',
#   'date_unixtime': '1678138605',
#   'edited': '2023-03-07T00:37:08',
#   'edited_unixtime': '1678138628',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': [{'type': 'link',
#     'text': 'https://tvims.nsu.ru/chernova/sibguti/ms-sibguti.pdf'}],
#   'text_entities': [{'type': 'link',
#     'text': 'https://tvims.nsu.ru/chernova/sibguti/ms-sibguti.pdf'}]},
#  {'id': 165,
#   'type': 'message',
#   'date': '2023-03-08T11:21:49',
#   'date_unixtime': '1678263709',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'file': '(File not included. Change data exporting settings to download.)',
#   'thumbnail': '(File not included. Change data exporting settings to download.)',
#   'media_type': 'sticker',
#   'sticker_emoji': '👋',
#   'duration_seconds': 2,
#   'width': 512,
#   'height': 471,
#   'text': '',
#   'text_entities': []},
#  {'id': 166,
#   'type': 'message',
#   'date': '2023-03-08T23:26:37',
#   'date_unixtime': '1678307197',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'forwarded_from': 'Аня ❤️',
#   'text': [{'type': 'link',
#     'text': 'https://www.hse.ru/edu/courses/471047597'}],
#   'text_entities': [{'type': 'link',
#     'text': 'https://www.hse.ru/edu/courses/471047597'}]},
#  {'id': 167,
#   'type': 'message',
#   'date': '2023-03-08T23:34:58',
#   'date_unixtime': '1678307698',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': [{'type': 'link',
#     'text': 'https://stylecaster.com/prince-harry-spare/#slide-10'}],
#   'text_entities': [{'type': 'link',
#     'text': 'https://stylecaster.com/prince-harry-spare/#slide-10'}]},
#  {'id': 168,
#   'type': 'message',
#   'date': '2023-03-09T19:00:57',
#   'date_unixtime': '1678377657',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'forwarded_from': 'Аня ❤️',
#   'file': '(File not included. Change data exporting settings to download.)',
#   'mime_type': 'video/x-matroska',
#   'text': '',
#   'text_entities': []},
#  {'id': 169,
#   'type': 'message',
#   'date': '2023-03-11T21:54:10',
#   'date_unixtime': '1678560850',
#   'edited': '2023-03-11T21:57:46',
#   'edited_unixtime': '1678561066',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'photo': '(File not included. Change data exporting settings to download.)',
#   'width': 1201,
#   'height': 148,
#   'text': 'Кст по второй твоей задачки с мл идеи:\nКак модифицировать SVM для неразделимых данных?\n1) Применить ядровой метод\n2) Добавить штраф за нарушения',
#   'text_entities': [{'type': 'plain',
#     'text': 'Кст по второй твоей задачки с мл идеи:\nКак модифицировать SVM для неразделимых данных?\n1) Применить ядровой метод\n2) Добавить штраф за нарушения'}]},
#  {'id': 170,
#   'type': 'message',
#   'date': '2023-03-12T14:23:31',
#   'date_unixtime': '1678620211',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'Хеллоу',
#   'text_entities': [{'type': 'plain', 'text': 'Хеллоу'}]},
#  {'id': 171,
#   'type': 'message',
#   'date': '2023-03-12T21:16:41',
#   'date_unixtime': '1678645001',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'Lesson 11: 🛄 Reading 🛄 Listeing\nLesson 14: 🛄 Writing task: essay',
#   'text_entities': [{'type': 'plain',
#     'text': 'Lesson 11: 🛄 Reading 🛄 Listeing\nLesson 14: 🛄 Writing task: essay'}]},
#  {'id': 172,
#   'type': 'message',
#   'date': '2023-03-12T21:18:46',
#   'date_unixtime': '1678645126',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'forwarded_from': 'Platon Promyslov',
#   'text': ['Здравствуйте, уважаемые слушатели курса!\n\nОтправляю ДЗ по сегодняшнему семинару. Дедлайн -- 12.03.2023 23:59. Решения сдаются через ',
#    {'type': 'text_link',
#     'text': 'гугл-форму',
#     'href': 'https://docs.google.com/forms/d/e/1FAIpQLSc6rEtEB5HwnXzcPFM9YiJ3TMQUjFQ_wcH6H4KCHbmqCqpxZQ/viewform?usp=sf_link'},
#    '.\n\nУбедительная просьба сдать ДЗ в формате pdf-файла с названием формата: Surname_Name_HWM_1.pdf'],
#   'text_entities': [{'type': 'plain',
#     'text': 'Здравствуйте, уважаемые слушатели курса!\n\nОтправляю ДЗ по сегодняшнему семинару. Дедлайн -- 12.03.2023 23:59. Решения сдаются через '},
#    {'type': 'text_link',
#     'text': 'гугл-форму',
#     'href': 'https://docs.google.com/forms/d/e/1FAIpQLSc6rEtEB5HwnXzcPFM9YiJ3TMQUjFQ_wcH6H4KCHbmqCqpxZQ/viewform?usp=sf_link'},
#    {'type': 'plain',
#     'text': '.\n\nУбедительная просьба сдать ДЗ в формате pdf-файла с названием формата: Surname_Name_HWM_1.pdf'}]},
#  {'id': 173,
#   'type': 'message',
#   'date': '2023-03-12T21:18:46',
#   'date_unixtime': '1678645126',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'forwarded_from': 'Platon Promyslov',
#   'file': '(File not included. Change data exporting settings to download.)',
#   'thumbnail': '(File not included. Change data exporting settings to download.)',
#   'mime_type': 'application/pdf',
#   'text': '',
#   'text_entities': []},
#  {'id': 174,
#   'type': 'message',
#   'date': '2023-03-12T21:39:18',
#   'date_unixtime': '1678646358',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'A Ever since the unguentaria plied their trade in ancient Rome, perfumers have to keep abreast of changing fashions. These days, they have several thousand ingredients to choose from when creating new scents, but there is always demand for new combinations. The bigger the ‘palette’ of smells, the better the perfumer’s chance of creating something fresh and appealing. Even with everyday products such as shampoo and soap, kitchen cleaners and washing powders, consumers are becoming increasingly fussy. And many of today’s fragrances have to survive tougher treatment than ever before, resisting the destructive power of bleach or a high temperature wash cycle. Chemists can create new smells from synthetic molecules, and a growing number of the odours on the perfumer’s palette are artificial. But nature has been in the business far longer.\n\nB The island of Madagascar is an evolutionary hot spot: 85% of its plants are unique, making it an ideal source for novel fragrances. Last October, Quest International, a company that develops fragrances for everything from the most delicate perfumes to cleaning products, sent an expedition to Madagascar in pursuit of some of nature’s most novel fragrances. With some simple technology, borrowed from the pollution monitoring industry, and a fair amount of ingenuity, the perfume hunters bagged 20 promising new aromas in the Madagascar rainforest. Each day the team set out from their ‘hotel’ – a wooden hut lit by kerosene lamps, and trailed up and down paths and animal tracks, exploring the thick vegetation up to 10 meters on either side of the trail. Some smells came from obvious places, often big snowy flowers within easy reach. Others were harder to pin down. ‘Often it was the very small flowers that were much more interesting,’ says Clery. After the luxuriance of the rainforest, the little-known island of Nosy Hara was a stark, dry place geologically and biologically very different from the mainland. ‘Apart from two beaches, the rest of the island is impenetrable, except by hacking through the bush,’ adds Clery. One of the biggest prizes here was a sweet-smelling sap weeping from the gnarled branches of some ancient shrubby trees in the parched interior. So far, no one has been able to identify the plant.\n\nC With most flowers or fruits, the hunters used a technique originally designed to trap and identify air pollutants. The technique itself is relatively simple. A glass bell jar or flask is fitted over the flower. The fragrance molecules are trapped in this ‘headspace’ and can be extracted by pumping the air out over a series of filters which absorb different types of volatile molecules. Back home in the laboratory, the molecules are flushed out of the filters and injected into a gas chromatograph for analysis. If it is impossible to attach the headspace gear, hunters fix an absorbent probe close to the source of the smell. The probe looks something like a hypodermic syringe, except that the ‘needle’ is made of silicone rubber which soaks up molecules from the air. After a few hours, the hunters retract the rubber needle and seal the tube, keeping the odour molecules inside until they can be injected into the gas chromatograph in the laboratory.\n\nD Some of the most promising fragrances were those given off by resins that oozed from the bark of trees. Resins are the source of many traditional perfumes, including frankincense and myrrh. The most exciting resin came from a Calophyllum tree, which produces a strongly scented medicinal oil. The sap of this Calophyllum smelt rich and aromatic, a little like church incense. But it also smelt of something that the fragrance industry learnt to live without: castoreum, a substance extracted from the musk glands of beavers and once a key ingredient in many perfumes. The company does not use animal products any longer, but it was wonderful to find a tree with an animal smell.',
#   'text_entities': [{'type': 'plain',
#     'text': 'A Ever since the unguentaria plied their trade in ancient Rome, perfumers have to keep abreast of changing fashions. These days, they have several thousand ingredients to choose from when creating new scents, but there is always demand for new combinations. The bigger the ‘palette’ of smells, the better the perfumer’s chance of creating something fresh and appealing. Even with everyday products such as shampoo and soap, kitchen cleaners and washing powders, consumers are becoming increasingly fussy. And many of today’s fragrances have to survive tougher treatment than ever before, resisting the destructive power of bleach or a high temperature wash cycle. Chemists can create new smells from synthetic molecules, and a growing number of the odours on the perfumer’s palette are artificial. But nature has been in the business far longer.\n\nB The island of Madagascar is an evolutionary hot spot: 85% of its plants are unique, making it an ideal source for novel fragrances. Last October, Quest International, a company that develops fragrances for everything from the most delicate perfumes to cleaning products, sent an expedition to Madagascar in pursuit of some of nature’s most novel fragrances. With some simple technology, borrowed from the pollution monitoring industry, and a fair amount of ingenuity, the perfume hunters bagged 20 promising new aromas in the Madagascar rainforest. Each day the team set out from their ‘hotel’ – a wooden hut lit by kerosene lamps, and trailed up and down paths and animal tracks, exploring the thick vegetation up to 10 meters on either side of the trail. Some smells came from obvious places, often big snowy flowers within easy reach. Others were harder to pin down. ‘Often it was the very small flowers that were much more interesting,’ says Clery. After the luxuriance of the rainforest, the little-known island of Nosy Hara was a stark, dry place geologically and biologically very different from the mainland. ‘Apart from two beaches, the rest of the island is impenetrable, except by hacking through the bush,’ adds Clery. One of the biggest prizes here was a sweet-smelling sap weeping from the gnarled branches of some ancient shrubby trees in the parched interior. So far, no one has been able to identify the plant.\n\nC With most flowers or fruits, the hunters used a technique originally designed to trap and identify air pollutants. The technique itself is relatively simple. A glass bell jar or flask is fitted over the flower. The fragrance molecules are trapped in this ‘headspace’ and can be extracted by pumping the air out over a series of filters which absorb different types of volatile molecules. Back home in the laboratory, the molecules are flushed out of the filters and injected into a gas chromatograph for analysis. If it is impossible to attach the headspace gear, hunters fix an absorbent probe close to the source of the smell. The probe looks something like a hypodermic syringe, except that the ‘needle’ is made of silicone rubber which soaks up molecules from the air. After a few hours, the hunters retract the rubber needle and seal the tube, keeping the odour molecules inside until they can be injected into the gas chromatograph in the laboratory.\n\nD Some of the most promising fragrances were those given off by resins that oozed from the bark of trees. Resins are the source of many traditional perfumes, including frankincense and myrrh. The most exciting resin came from a Calophyllum tree, which produces a strongly scented medicinal oil. The sap of this Calophyllum smelt rich and aromatic, a little like church incense. But it also smelt of something that the fragrance industry learnt to live without: castoreum, a substance extracted from the musk glands of beavers and once a key ingredient in many perfumes. The company does not use animal products any longer, but it was wonderful to find a tree with an animal smell.'}]},
#  {'id': 175,
#   'type': 'message',
#   'date': '2023-03-12T21:39:18',
#   'date_unixtime': '1678646358',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'E The group also set out from the island to capture the smell of coral reefs. Odours that conjure up sun kissed seas are highly sought after by the perfume industry. ‘From the ocean, the only thing we have is seaweed, and that has a dark and heavy aroma. We hope to find something unique among the corals,’ says Clery. The challenge for the hunters was to extract a smell from water rather than air. This was an opportunity to try Clery’s new ‘aquaspace’ apparatus – a set of filters that work underwater. On Nosy Hara, jars were fixed over knobs of coral about 2 meters down and water pumped out over the absorbent filters. So, what does coral smell like? ‘It’s a bit like lobster and crab,’ explains Clary. The team’s task now is to recreate the best of the captured smells. First, they must identify the molecules that make up each fragrance. Some ingredients may be quite common chemicals. But some may be completely novel, or they may be too complex or expensive to make in the lab. The challenge then is to conjure up the fragrances with more readily available materials. ‘We can avoid the need to import plants from the rainforest by creating the smell with a different set of chemicals from those in the original material,’ says Clery. ‘If we get it right, you can sniff the sample and it will transport you straight back to the moment you smelt it in the rainforest.’\n\n \n\nQuestions 14-18. The reading passage has seven paragraphs, A-E. Which paragraphs contain the following details. Write the correct number, A-E, in boxes accordingly.\n\nN.B. You may use any letter more than once.\n\n14 One currently preferred spot to pick up plants for novel finding. Answer\nD\n\n15 A new task seems to be promising yet producing limited findings in fragrance source. Answer\nE\n\n16 The demanding conditions for fragrance to endure. Answer\n\n17 A substitute for substance no longer available to the perfume manufacture. Answer\nD\n\n18 Description of an outdoor expedition on land chasing new fragrances',
#   'text_entities': [{'type': 'plain',
#     'text': 'E The group also set out from the island to capture the smell of coral reefs. Odours that conjure up sun kissed seas are highly sought after by the perfume industry. ‘From the ocean, the only thing we have is seaweed, and that has a dark and heavy aroma. We hope to find something unique among the corals,’ says Clery. The challenge for the hunters was to extract a smell from water rather than air. This was an opportunity to try Clery’s new ‘aquaspace’ apparatus – a set of filters that work underwater. On Nosy Hara, jars were fixed over knobs of coral about 2 meters down and water pumped out over the absorbent filters. So, what does coral smell like? ‘It’s a bit like lobster and crab,’ explains Clary. The team’s task now is to recreate the best of the captured smells. First, they must identify the molecules that make up each fragrance. Some ingredients may be quite common chemicals. But some may be completely novel, or they may be too complex or expensive to make in the lab. The challenge then is to conjure up the fragrances with more readily available materials. ‘We can avoid the need to import plants from the rainforest by creating the smell with a different set of chemicals from those in the original material,’ says Clery. ‘If we get it right, you can sniff the sample and it will transport you straight back to the moment you smelt it in the rainforest.’\n\n \n\nQuestions 14-18. The reading passage has seven paragraphs, A-E. Which paragraphs contain the following details. Write the correct number, A-E, in boxes accordingly.\n\nN.B. You may use any letter more than once.\n\n14 One currently preferred spot to pick up plants for novel finding. Answer\nD\n\n15 A new task seems to be promising yet producing limited findings in fragrance source. Answer\nE\n\n16 The demanding conditions for fragrance to endure. Answer\n\n17 A substitute for substance no longer available to the perfume manufacture. Answer\nD\n\n18 Description of an outdoor expedition on land chasing new fragrances'}]},
#  {'id': 176,
#   'type': 'message',
#   'date': '2023-03-12T21:39:27',
#   'date_unixtime': '1678646367',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': '19 Manufacturers can choose to use synthetic odours for the perfume nowadays. Answer\nTRUE\n\n20 Madagascar is chosen to be a place for hunting plants which are rare in other parts of the world. Answer\nTRUE\n\n21 Capturing the smell is one of the most important things for creating new aromas. Answer\n\n22 The technique the hunters used to trap fragrance molecules was their own invention. Answer\n\n23 Most customers prefer the perfume made of substance extracted from the musk glands of animals',
#   'text_entities': [{'type': 'plain',
#     'text': '19 Manufacturers can choose to use synthetic odours for the perfume nowadays. Answer\nTRUE\n\n20 Madagascar is chosen to be a place for hunting plants which are rare in other parts of the world. Answer\nTRUE\n\n21 Capturing the smell is one of the most important things for creating new aromas. Answer\n\n22 The technique the hunters used to trap fragrance molecules was their own invention. Answer\n\n23 Most customers prefer the perfume made of substance extracted from the musk glands of animals'}]},
#  {'id': 177,
#   'type': 'message',
#   'date': '2023-03-12T22:14:45',
#   'date_unixtime': '1678648485',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'ОТВЕТ 1:\nГлавная цель SVM (Support Vector Machine) как классификатора - это разделение данных на классы, максимизируя расстояние между ними.\n\nSVM строит гиперплоскость в многомерном пространстве, которая разделяет точки, относящиеся к разным классам. Гиперплоскость выбирается таким образом, чтобы максимизировать расстояние между точками каждого класса, ближайших к гиперплоскости. Эти точки называются опорными векторами, и они играют важную роль в SVM.',
#   'text_entities': [{'type': 'plain',
#     'text': 'ОТВЕТ 1:\nГлавная цель SVM (Support Vector Machine) как классификатора - это разделение данных на классы, максимизируя расстояние между ними.\n\nSVM строит гиперплоскость в многомерном пространстве, которая разделяет точки, относящиеся к разным классам. Гиперплоскость выбирается таким образом, чтобы максимизировать расстояние между точками каждого класса, ближайших к гиперплоскости. Эти точки называются опорными векторами, и они играют важную роль в SVM.'}]},
#  {'id': 178,
#   'type': 'message',
#   'date': '2023-03-12T22:15:25',
#   'date_unixtime': '1678648525',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'ОТВЕТ 2:\nЕсли классы не являются линейно разделимыми, то метод SVM может быть модифицирован с помощью следующих методов:\n\n1) Использование ядерного метода. Ядерные методы SVM используются для перевода данных в пространство более высокой размерности, где классы могут быть лучше разделимы. \n\n2) Использование методов мягкой классификации. Вместо того, чтобы стремиться к идеальному разделению классов, метод мягкой классификации позволяет некоторым точкам классифицироваться неправильно, что может привести к более точной модели в целом.\n\n3) Использование ансамблевых методов. Ансамблевые методы, такие как случайный лес или градиентный бустинг, могут использоваться вместе с SVM для улучшения его точности и устойчивости.',
#   'text_entities': [{'type': 'plain',
# ...
#   'date': '2023-05-15T12:10:02',
#   'date_unixtime': '1684141802',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'forwarded_from': 'Аня ❤️',
#   'text': 'Я пошла в хлеб насущный позавтракать, сижу на веранде, пью кофе, ботаю проект',
#   'text_entities': [{'type': 'plain',
#     'text': 'Я пошла в хлеб насущный позавтракать, сижу на веранде, пью кофе, ботаю проект'}]},
#  {'id': 1177,
#   'type': 'message',
#   'date': '2023-05-15T12:10:14',
#   'date_unixtime': '1684141814',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'пишут отчет',
#   'text_entities': [{'type': 'plain', 'text': 'пишут отчет'}]},
#  {'id': 1178,
#   'type': 'message',
#   'date': '2023-05-15T12:10:20',
#   'date_unixtime': '1684141820',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'такое счастье что сменили задачу',
#   'text_entities': [{'type': 'plain',
#     'text': 'такое счастье что сменили задачу'}]},
#  {'id': 1179,
#   'type': 'message',
#   'date': '2023-05-15T12:10:25',
#   'date_unixtime': '1684141825',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'у меня теперь проект самое то',
#   'text_entities': [{'type': 'plain',
#     'text': 'у меня теперь проект самое то'}]},
#  {'id': 1180,
#   'type': 'message',
#   'date': '2023-05-15T12:10:39',
#   'date_unixtime': '1684141839',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'photo': '(File not included. Change data exporting settings to download.)',
#   'width': 1280,
#   'height': 277,
#   'text': '',
#   'text_entities': []},
#  {'id': 1181,
#   'type': 'message',
#   'date': '2023-05-15T12:10:46',
#   'date_unixtime': '1684141846',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'просто все галочки)',
#   'text_entities': [{'type': 'plain', 'text': 'просто все галочки)'}]},
#  {'id': 1182,
#   'type': 'message',
#   'date': '2023-05-15T12:28:52',
#   'date_unixtime': '1684142932',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'photo': '(File not included. Change data exporting settings to download.)',
#   'width': 591,
#   'height': 1280,
#   'text': '',
#   'text_entities': []},
#  {'id': 1183,
#   'type': 'message',
#   'date': '2023-05-15T12:29:15',
#   'date_unixtime': '1684142955',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'file': '(File not included. Change data exporting settings to download.)',
#   'thumbnail': '(File not included. Change data exporting settings to download.)',
#   'media_type': 'sticker',
#   'sticker_emoji': '🕺',
#   'width': 512,
#   'height': 512,
#   'text': '',
#   'text_entities': []},
#  {'id': 1184,
#   'type': 'message',
#   'date': '2023-05-15T12:44:39',
#   'date_unixtime': '1684143879',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'reply_to_message_id': 1182,
#   'text': 'А это что',
#   'text_entities': [{'type': 'plain', 'text': 'А это что'}]},
#  {'id': 1185,
#   'type': 'message',
#   'date': '2023-05-15T12:44:42',
#   'date_unixtime': '1684143882',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'Супер!!',
#   'text_entities': [{'type': 'plain', 'text': 'Супер!!'}]},
#  {'id': 1186,
#   'type': 'message',
#   'date': '2023-05-15T12:44:49',
#   'date_unixtime': '1684143889',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'Рад за вас!',
#   'text_entities': [{'type': 'plain', 'text': 'Рад за вас!'}]},
#  {'id': 1187,
#   'type': 'message',
#   'date': '2023-05-15T12:44:56',
#   'date_unixtime': '1684143896',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'file': '(File not included. Change data exporting settings to download.)',
#   'thumbnail': '(File not included. Change data exporting settings to download.)',
#   'media_type': 'sticker',
#   'sticker_emoji': '🐱',
#   'duration_seconds': 2,
#   'width': 512,
#   'height': 512,
#   'text': '',
#   'text_entities': []},
#  {'id': 1188,
#   'type': 'message',
#   'date': '2023-05-15T12:45:17',
#   'date_unixtime': '1684143917',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'reply_to_message_id': 1182,
#   'text': 'График отключения горячей воды в квартире',
#   'text_entities': [{'type': 'plain',
#     'text': 'График отключения горячей воды в квартире'}]},
#  {'id': 1189,
#   'type': 'message',
#   'date': '2023-05-15T12:45:30',
#   'date_unixtime': '1684143930',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'Ммм',
#   'text_entities': [{'type': 'plain', 'text': 'Ммм'}]},
#  {'id': 1190,
#   'type': 'message',
#   'date': '2023-05-15T12:46:39',
#   'date_unixtime': '1684143999',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'Что как у вас дела?',
#   'text_entities': [{'type': 'plain', 'text': 'Что как у вас дела?'}]},
#  {'id': 1191,
#   'type': 'message',
#   'date': '2023-05-15T12:48:12',
#   'date_unixtime': '1684144092',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'Я пошел писать физику)',
#   'text_entities': [{'type': 'plain', 'text': 'Я пошел писать физику)'}]},
#  {'id': 1192,
#   'type': 'message',
#   'date': '2023-05-15T12:48:12',
#   'date_unixtime': '1684144092',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'На 5 часов)',
#   'text_entities': [{'type': 'plain', 'text': 'На 5 часов)'}]},
#  {'id': 1193,
#   'type': 'message',
#   'date': '2023-05-15T12:48:32',
#   'date_unixtime': '1684144112',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'Удачи!!',
#   'text_entities': [{'type': 'plain', 'text': 'Удачи!!'}]},
#  {'id': 1194,
#   'type': 'message',
#   'date': '2023-05-15T12:48:39',
#   'date_unixtime': '1684144119',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'file': '(File not included. Change data exporting settings to download.)',
#   'thumbnail': '(File not included. Change data exporting settings to download.)',
#   'media_type': 'sticker',
#   'sticker_emoji': '😘',
#   'duration_seconds': 3,
#   'width': 512,
#   'height': 384,
#   'text': '',
#   'text_entities': []},
#  {'id': 1195,
#   'type': 'message',
#   'date': '2023-05-15T12:48:51',
#   'date_unixtime': '1684144131',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'Спасибо!',
#   'text_entities': [{'type': 'plain', 'text': 'Спасибо!'}]},
#  {'id': 1196,
#   'type': 'message',
#   'date': '2023-05-15T16:04:20',
#   'date_unixtime': '1684155860',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'forwarded_from': 'ПМИ ФКН — неучебное',
#   'photo': '(File not included. Change data exporting settings to download.)',
#   'width': 960,
#   'height': 1280,
#   'text': 'Тут в КЦ мерч раздают, отвечают на вопросики, а в 18:00 будет лекция от Маркета 🌞',
#   'text_entities': [{'type': 'plain',
#     'text': 'Тут в КЦ мерч раздают, отвечают на вопросики, а в 18:00 будет лекция от Маркета 🌞'}]},
#  {'id': 1197,
#   'type': 'message',
#   'date': '2023-05-15T16:06:29',
#   'date_unixtime': '1684155989',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'Напиши еще плиз как освободишься где шницель купить',
#   'text_entities': [{'type': 'plain',
#     'text': 'Напиши еще плиз как освободишься где шницель купить'}]},
#  {'id': 1198,
#   'type': 'message',
#   'date': '2023-05-15T16:43:35',
#   'date_unixtime': '1684158215',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'Так, папа сегодня еще подошел, перешлю, что ему прислали. Но есть ситуация даже важней: на каком-то анализе у твоей мамы увидели утолщение стенки желудка. Папа сказал, что это либо ошибка, либо сильное отклонение от от нормы. Поэтому надо сделать фгдс в обязательно хорошем месте с множественной биопсией (чтобы взяли несколько образцов). Важно также отправить эти образцы в хорошее место, так как папа сказал, что часто такому материалу ставят ложноотрицательный ответ. Почему это важно: если это не ошибка, то, наверное, это какое-то образование (непонятного характера)',
#   'text_entities': [{'type': 'plain',
#     'text': 'Так, папа сегодня еще подошел, перешлю, что ему прислали. Но есть ситуация даже важней: на каком-то анализе у твоей мамы увидели утолщение стенки желудка. Папа сказал, что это либо ошибка, либо сильное отклонение от от нормы. Поэтому надо сделать фгдс в обязательно хорошем месте с множественной биопсией (чтобы взяли несколько образцов). Важно также отправить эти образцы в хорошее место, так как папа сказал, что часто такому материалу ставят ложноотрицательный ответ. Почему это важно: если это не ошибка, то, наверное, это какое-то образование (непонятного характера)'}]},
#  {'id': 1199,
#   'type': 'message',
#   'date': '2023-05-15T16:44:58',
#   'date_unixtime': '1684158298',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'photo': '(File not included. Change data exporting settings to download.)',
#   'width': 591,
#   'height': 1280,
#   'text': '',
#   'text_entities': []},
#  {'id': 1200,
#   'type': 'message',
#   'date': '2023-05-15T16:45:48',
#   'date_unixtime': '1684158348',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'forwarded_from': 'Yaroslav',
#   'photo': '(File not included. Change data exporting settings to download.)',
#   'width': 960,
#   'height': 1280,
#   'text': '',
#   'text_entities': []},
#  {'id': 1201,
#   'type': 'message',
#   'date': '2023-05-15T17:23:24',
#   'date_unixtime': '1684160604',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'forwarded_from': 'Russian Hackers | Хакатоны',
#   'text': [{'type': 'text_link',
#     'text': '\u200b\u200b',
#     'href': 'https://telegra.ph/file/1437063a9ac2a54b9dcab.jpg'},
#    {'type': 'bold', 'text': 'Global AI Challenge'},
#    '\n\n• Описание: онлайн-конкурс для разработчиков в области медицины AI4Medicine — молодых специалистов, преподавателей, аспирантов, обучающихся ведущих образовательных организаций России и стран ближнего зарубежья. Организатор — Университет Иннополис. Задача: диагностика внутричерепных кровоизлияний с помощью алгоритмов обучения без учителя\n\n• Даты проведения: 10 мая — 23 июня\n\n• Место проведения: online\n\n• Регистрация: до 22 мая\n\n• Ссылка: ',
#    {'type': 'link', 'text': 'rhck.me/globalaiinnopolis'},
#    '\n\n• Особенности: призовой фонд — 400 000 ₽\n\n',
#    {'type': 'hashtag', 'text': '#event'},
#    ' ',
#    {'type': 'mention', 'text': '@RussianHackers_Channel'},
#    ''],
#   'text_entities': [{'type': 'text_link',
#     'text': '\u200b\u200b',
#     'href': 'https://telegra.ph/file/1437063a9ac2a54b9dcab.jpg'},
#    {'type': 'bold', 'text': 'Global AI Challenge'},
#    {'type': 'plain',
#     'text': '\n\n• Описание: онлайн-конкурс для разработчиков в области медицины AI4Medicine — молодых специалистов, преподавателей, аспирантов, обучающихся ведущих образовательных организаций России и стран ближнего зарубежья. Организатор — Университет Иннополис. Задача: диагностика внутричерепных кровоизлияний с помощью алгоритмов обучения без учителя\n\n• Даты проведения: 10 мая — 23 июня\n\n• Место проведения: online\n\n• Регистрация: до 22 мая\n\n• Ссылка: '},
#    {'type': 'link', 'text': 'rhck.me/globalaiinnopolis'},
#    {'type': 'plain',
#     'text': '\n\n• Особенности: призовой фонд — 400 000 ₽\n\n'},
#    {'type': 'hashtag', 'text': '#event'},
#    {'type': 'plain', 'text': ' '},
#    {'type': 'mention', 'text': '@RussianHackers_Channel'},
#    {'type': 'plain', 'text': ''}]},
#  {'id': 1202,
#   'type': 'message',
#   'date': '2023-05-15T17:43:52',
#   'date_unixtime': '1684161832',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'photo': '(File not included. Change data exporting settings to download.)',
#   'width': 960,
#   'height': 1280,
#   'text': '',
#   'text_entities': []},
#  {'id': 1203,
#   'type': 'message',
#   'date': '2023-05-15T17:43:55',
#   'date_unixtime': '1684161835',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'photo': '(File not included. Change data exporting settings to download.)',
#   'width': 960,
#   'height': 1280,
#   'text': '',
#   'text_entities': []},
#  {'id': 1204,
#   'type': 'message',
#   'date': '2023-05-15T17:44:06',
#   'date_unixtime': '1684161846',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'Решайся в первом qr code',
#   'text_entities': [{'type': 'plain', 'text': 'Решайся в первом qr code'}]},
#  {'id': 1205,
#   'type': 'message',
#   'date': '2023-05-15T17:44:12',
#   'date_unixtime': '1684161852',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'Во втором решай задачи',
#   'text_entities': [{'type': 'plain', 'text': 'Во втором решай задачи'}]},
#  {'id': 1206,
#   'type': 'message',
#   'date': '2023-05-15T17:44:16',
#   'date_unixtime': '1684161856',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'И дадут мерч',
#   'text_entities': [{'type': 'plain', 'text': 'И дадут мерч'}]},
#  {'id': 1207,
#   'type': 'message',
#   'date': '2023-05-15T17:45:58',
#   'date_unixtime': '1684161958',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'Что дают? Сколько надо решить?',
#   'text_entities': [{'type': 'plain',
#     'text': 'Что дают? Сколько надо решить?'}]},
#  {'id': 1208,
#   'type': 'message',
#   'date': '2023-05-15T17:46:01',
#   'date_unixtime': '1684161961',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'Ты решал?',
#   'text_entities': [{'type': 'plain', 'text': 'Ты решал?'}]},
#  {'id': 1209,
#   'type': 'message',
#   'date': '2023-05-15T17:46:10',
#   'date_unixtime': '1684161970',
#   'edited': '2023-05-15T17:46:17',
#   'edited_unixtime': '1684161977',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'Я только приехал)',
#   'text_entities': [{'type': 'plain', 'text': 'Я только приехал)'}]},
#  {'id': 1210,
#   'type': 'message',
#   'date': '2023-05-15T17:46:13',
#   'date_unixtime': '1684161973',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'reply_to_message_id': 1207,
#   'text': 'Хз',
#   'text_entities': [{'type': 'plain', 'text': 'Хз'}]},
#  {'id': 1211,
#   'type': 'message',
#   'date': '2023-05-15T17:46:20',
#   'date_unixtime': '1684161980',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'reply_to_message_id': 1210,
#   'text': 'Узнай)',
#   'text_entities': [{'type': 'plain', 'text': 'Узнай)'}]},
#  {'id': 1212,
#   'type': 'message',
#   'date': '2023-05-15T17:46:25',
#   'date_unixtime': '1684161985',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'Ну там кружки',
#   'text_entities': [{'type': 'plain', 'text': 'Ну там кружки'}]},
#  {'id': 1213,
#   'type': 'message',
#   'date': '2023-05-15T17:46:28',
#   'date_unixtime': '1684161988',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'Термо',
#   'text_entities': [{'type': 'plain', 'text': 'Термо'}]},
#  {'id': 1214,
#   'type': 'message',
#   'date': '2023-05-15T17:46:30',
#   'date_unixtime': '1684161990',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'И футболки',
#   'text_entities': [{'type': 'plain', 'text': 'И футболки'}]},
#  {'id': 1215,
#   'type': 'message',
#   'date': '2023-05-15T17:46:33',
#   'date_unixtime': '1684161993',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'И шопер',
#   'text_entities': [{'type': 'plain', 'text': 'И шопер'}]},
#  {'id': 1216,
#   'type': 'message',
#   'date': '2023-05-15T17:46:34',
#   'date_unixtime': '1684161994',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'Хехех',
#   'text_entities': [{'type': 'plain', 'text': 'Хехех'}]},
#  {'id': 1217,
#   'type': 'message',
#   'date': '2023-05-15T17:46:47',
#   'date_unixtime': '1684162007',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'Я уже ушел оттуда',
#   'text_entities': [{'type': 'plain', 'text': 'Я уже ушел оттуда'}]},
#  {'id': 1218,
#   'type': 'message',
#   'date': '2023-05-15T17:46:57',
#   'date_unixtime': '1684162017',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'А как забрать подарок?',
#   'text_entities': [{'type': 'plain', 'text': 'А как забрать подарок?'}]},
#  {'id': 1219,
#   'type': 'message',
#   'date': '2023-05-15T17:46:58',
#   'date_unixtime': '1684162018',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'Кушшшатт',
#   'text_entities': [{'type': 'plain', 'text': 'Кушшшатт'}]},
#  {'id': 1220,
#   'type': 'message',
#   'date': '2023-05-15T17:47:00',
#   'date_unixtime': '1684162020',
#   'edited': '2023-05-15T17:47:10',
#   'edited_unixtime': '1684162030',
#   'from': 'No',
#   'from_id': 'user5982387868',
#   'text': 'Кушшать',
#   'text_entities': [{'type': 'plain', 'text': 'Кушшать'}]},
#  {'id': 1221,
#   'type': 'message',
#   'date': '2023-05-15T17:47:08',
#   'date_unixtime': '1684162028',
#   'from': 'Аня ❤️',
#   'from_id': 'user348973081',
#   'text': 'А ты сегодня на покре?',
#   'text_entities': [{'type': 'plain', 'text': 'А ты сегодня на покре?'}]},
#  ...]

# %%
import json
from pathlib import Path


from datetime import datetime

def get_dialogues(dump_path, MAX_CONTEXT_LEN = 1200, MAX_TEXT_LEN = 1200, MY_NAME = 'No'):

    with open(dump_path) as messages_file:
            messages = json.load(messages_file)['messages']

            
    dialogues = []
    last_post_date = None
    last_sender = None
    
    curr_input = ''
    curr_output = ''
    curr_context = ''
    
    print(len(messages))

    for message in messages:
        #remove forwarded messages
        if message.get('forwarded_from', None):
            continue
        
        if message.get('text', None):
            txt = message.get('text', None)
            if len(txt) > MAX_TEXT_LEN:
                continue 
            if re.search("(?P<url>https?://[^\s]+)", str(txt)): # remove links 
                continue   
        elif message.get('sticker_emoji', None):
            txt = message.get('sticker_emoji', None)
        else:
            continue
            
        curr_date = datetime.strptime(message.get('date', None),'%Y-%m-%dT%H:%M:%S') 
        curr_sender = message.get('from', None)
        
        if curr_date is None or curr_sender is None:
            continue 
        
        if last_post_date == None:
            last_post_date = curr_date
        if last_sender == None:
            last_sender = curr_sender
        
        if curr_sender == MY_NAME:
            curr_output = curr_output + str(txt) + ' \n '
        else:
            curr_input = curr_input + str(txt) + ' \n '
                
                
        if curr_sender != last_sender:
            dialogues.append({'context':curr_context, 'input':curr_input, 'output':curr_output})
            if len(curr_input) != 0:
                curr_context += 'АНЯ:' + curr_input
            if len(curr_output) != 0:
                curr_context += 'НИКИТА:' + curr_output
            curr_input = ''
            curr_output = ''
            

        if len(curr_context) > MAX_CONTEXT_LEN:
            curr_context = ''
        
        if (curr_date - last_post_date).seconds//3600 > 2: 
            
            last_post_date = None
            last_sender = None
            
            curr_input = ''
            curr_output = ''
            curr_context = ''  
        
        last_sender = curr_sender


        # TO-DO: catch reply_to_message_id
        
    return dialogues

# %%
check_message({'id': 111,
  'type': 'message',
  'date': '2023-02-27T22:33:22',
  'date_unixtime': '1677526402',
  'from': 'Аня ❤️',
  'from_id': 'user348973081',
  'text': [{'type': 'link',
    'text': 'https://docviewer.yandex.ru/view/1049160442/?page=3&*=3Z%%3D'}],
  'text_entities': [{'type': 'link',
    'text': 'https://docviewer.yandex.ru/view/1049160442/?page=3&*=3Z%%3D'}]}, 1000)
# Out:
# False

# %%
re.search("(?P<url>https?://[^\s]+)", '''[{'type': 'link',
   'text': 'https://docviewer.yandex.ru/view/1049160442/?page=3&*=3Z%%3D'}]''')
# Out:
# <re.Match object; span=(30, 479), match="https://docviewer.yandex.ru/view/1049160442/?page>

# %%
s= '''8 15\n\\             /\n.|           |.\n.|           |.\n..\\         /..\n...|       |...\n...|       |...\n....\\     /....\n.....\\___/.....\n2\ngin 2 %\ntonic 4 * \n 8 15\n\\             /\n.|           |.\n.|           |.\n..\\         /..\n...|       |...\n...|       |...\n....\\     /....\n.....\\___/.....\n2\ngin 2 %\ntonic 4 * \n \\             /\n.|***********|.\n.|***********|.\n..\\*********/..\n...|*******|...\n...|%%%%%%%|...\n....\\%%%%%/....\n.....\\___/..... \n \\             /\n.|***********|.\n.|***********|.\n..\\*********/..\n...|*******|...\n...|%%%%%%%|...\n....\\%%%%%/....\n.....\\___/..... \n '},
 {'context': 'АНЯ:😘 \n Оке приду через 5 минут \n НИКИТА:8 15\n\\             /\n.|           |.\n.|           |.\n..\\         /..\n...|       |...\n...|       |...\n....\\     /....\n.....\\___/.....\n2\ngin 2 %\ntonic 4 * \n 8 15\n\\             /\n.|           |.\n.|           |.\n..\\         /..\n...|       |...\n...|       |...\n....\\     /....\n.....\\___/.....\n2\ngin 2 %\ntonic 4 * \n \\             /\n.|***********|.\n.|***********|.\n..\\*********/..\n...|*******|...\n...|%%%%%%%|...\n....\\%%%%%/....\n.....\\___/..... \n \\             /\n.|***********|.\n.|***********|.\n..\\*********/..\n...|*******|...\n...|%%%%%%%|...\n....\\%%%%%/....\n.....\\___/..... \n '''

# %%
count_alphabetic_and_emojis(s)/len(s)
# Out:
# 0.05587989991659716

# %%
import json
from pathlib import Path
import re 
import emoji

from datetime import datetime

def count_alphabetic(input_string):
    count = 0
    
    for char in input_string:
        if char.isalpha():
            count += 1
    return count

def count_emojis(input_string):
    count = 0
    
    for char in input_string:
        if emoji.EMOJI_DATA:
            count += 1
    return count

def check_message(message, MAX_TEXT_LEN, symbols_treshold = 0.5):
    #remove forwarded messa
    if message.get('forwarded_from', None):
        return False
    
    if message.get('text', None):
        text = message.get('text', None)
        if len(text) > MAX_TEXT_LEN:
            return False 
        if re.search("(?P<url>https?://[^\s]+)", str(text)): # remove links 
            return False   
        alph_num = count_alphabetic(str(text))
        emoji_num = count_emojis(str(text))
        
        if (alph_num)/len(str(text)) < symbols_treshold:
            return False
    elif message.get('sticker_emoji', None):
        text = message.get('sticker_emoji', None)
    else:
        return False
        
    curr_date = datetime.strptime(message.get('date', None),'%Y-%m-%dT%H:%M:%S') 
    curr_sender = message.get('from_id', None)
    
    if curr_date is None or curr_sender is None:
        return False 
    
    return {'text':text, 'curr_date':curr_date, 'curr_sender':curr_sender}
    
    


def get_dialogues(dump_path, MAX_CONTEXT_LEN = 200, MAX_TEXT_LEN = 180, my_ids = ['user5982387868', 'user348898603'], prompt = ''): 
    # MAX_CONTEXT_LEN = 500, MAX_TEXT_LEN = 200,

    with open(dump_path) as messages_file:
            messages = json.load(messages_file)['messages']

            
    dialogues = []
    last_post_date = None
    last_sender = None
    last_anna_text = ''
    
    my_text = ''
    anna_text = ''
    curr_context = ''
    
    for message in messages:
        
        message = check_message(message, MAX_TEXT_LEN)
        if not message:
            continue
        else:
            curr_date = message['curr_date']
            curr_sender = message['curr_sender']
            curr_text = message['text']
        
        if last_post_date == None:
            last_post_date = curr_date
        if last_sender == None:
            last_sender = curr_sender
        
        
        if curr_sender != last_sender and curr_sender not in my_ids:
            #dialogues.append({'context':curr_context, 'instruction':anna_text, 'response':my_text})
            if len(anna_text) != 0:
                curr_context += ' Собеседник:' + anna_text + '\n'
            dialogues.append({'context':curr_context, 'response':my_text})
            if len(my_text) != 0:
                curr_context += ' Ты:' + my_text + '\n'
                
            last_anna_text = anna_text
            anna_text = ''
            my_text = ''
        
        if curr_sender in my_ids:
            my_text = my_text + str(curr_text) + ' \n'
        else:
            anna_text = anna_text + str(curr_text) + ' \n'

        
        if len(curr_context) > MAX_CONTEXT_LEN:
            curr_context = ''
        
        if (curr_date - last_post_date).seconds//3600 > 2: 
            
            last_post_date = None
            last_sender = None
            
            curr_input = ''
            curr_output = ''
            curr_context = ''  
        
        last_sender = curr_sender
        last_post_date = curr_date

        # TO-DO: catch reply_to_message_id
        
    return dialogues

# %%
import os
import glob

def find_json_files(folder_path, exceptions = ['']):
    json_files = []
    
    search_pattern = os.path.join(folder_path, '**', '*.json')
    
    for file_path in glob.iglob(search_pattern, recursive=True):
        if os.path.isfile(file_path) and file_path not in exceptions:
            json_files.append(file_path)
    
    return json_files

folder_path = '/home/box/digital_clone/dialogues'
#exceptions = ['/home/box/digital_clone/dialogues/tg_dialogues_with_anna_account_1.json']
exceptions = ['']

json_paths = find_json_files(folder_path, exceptions = exceptions)

if json_paths:
    print('-' * 110 )
    print('PARSED_PATHS:')
    print('-' * 110 )
    for json_file in json_paths:
        print(json_file)
else:
    print("There is no json files")
# Out:
# --------------------------------------------------------------------------------------------------------------
# PARSED_PATHS:
# --------------------------------------------------------------------------------------------------------------
# /home/box/digital_clone/dialogues/m_1.json
# /home/box/digital_clone/dialogues/anastasia.json
# /home/box/digital_clone/dialogues/colya.json
# /home/box/digital_clone/dialogues/dasha_hse.json
# /home/box/digital_clone/dialogues/genyaa.json
# /home/box/digital_clone/dialogues/mama.json
# /home/box/digital_clone/dialogues/tg_dialogues_with_anna_account_2.json
# /home/box/digital_clone/dialogues/misha.json
# /home/box/digital_clone/dialogues/zloy_chelovek.json
# /home/box/digital_clone/dialogues/nikita.json
# /home/box/digital_clone/dialogues/alan.json
# /home/box/digital_clone/dialogues/ekaterina.json
# /home/box/digital_clone/dialogues/vova.json
# /home/box/digital_clone/dialogues/dima.json
# /home/box/digital_clone/dialogues/tg_dialogues_with_anna_account_2_2.json

# %%
# prompt = '''Тебя зовут Никита. Тебе 21 год. У тебя есть девушка Аня, вы встречаетесь 2 года и ты ее очень любишь. 
# Ты общаешься с Аней, продолжи диалог: '''

all_dialogues = []


for path in json_paths:
    # диалоги с разных аккаунтов тг
    dialogues = get_dialogues(path)
    
    if path == '/home/box/digital_clone/dialogues/tg_dialogues_with_anna_account_2_2.json':
        all_dialogues += dialogues[:5000]
    else:
        all_dialogues += dialogues
    print(len(dialogues))
# Out:
# 235
# 353
# 79
# 2655
# 60
# 897
# 3475
# 5863
# 344
# 106
# 452
# 140
# 155
# 1214
# 23032

# %%
len(all_dialogues)
# Out:
# 21028

# %%
all_dialogues
# Out:
# [{'context': ' Собеседник:Почему ты тут в сети был \nА в вк нет? \n\n',
#   'response': 'Я случайно зашел в телегу ... \n'},
#  {'context': ' Собеседник:Почему ты тут в сети был \nА в вк нет? \n\n Ты:Я случайно зашел в телегу ... \n\n Собеседник:😄 \n\n',
#   'response': 'Аоаоаоаоаоа \n'},
#  {'context': ' Собеседник:Почему ты тут в сети был \nА в вк нет? \n\n Ты:Я случайно зашел в телегу ... \n\n Собеседник:😄 \n\n Ты:Аоаоаоаоаоа \n\n Собеседник:😴 \n\n',
#   'response': 'На какой акк ? \n'},
#  {'context': ' Собеседник:Почему ты тут в сети был \nА в вк нет? \n\n Ты:Я случайно зашел в телегу ... \n\n Собеседник:😄 \n\n Ты:Аоаоаоаоаоа \n\n Собеседник:😴 \n\n Ты:На какой акк ? \n\n Собеседник:На любой \nАхахх \n\n',
#   'response': 'Ок \n'},
#  {'context': ' Собеседник:Почему ты тут в сети был \nА в вк нет? \n\n Ты:Я случайно зашел в телегу ... \n\n Собеседник:😄 \n\n Ты:Аоаоаоаоаоа \n\n Собеседник:😴 \n\n Ты:На какой акк ? \n\n Собеседник:На любой \nАхахх \n\n Ты:Ок \n\n Собеседник:У тебя же их два? \nНе три?) \nАаа точно помню и 3 \n\n',
#   'response': 'Я хз \n'},
#  {'context': ' Собеседник:Не спи \nОй \nЗаходи в вк \n\n', 'response': '💃 \n'},
#  {'context': ' Собеседник:Ава супер \n\n', 'response': '🤗 \n'},
#  {'context': ' Собеседник:ТАКУЮ АВАТАРКУ УПУСКАЕШЬ \nНУ МДАААА \nНИКИТА \n😐 \nУ меня вопрос \n\n',
#   'response': '😳 \n'},
#  {'context': ' Собеседник:ТАКУЮ АВАТАРКУ УПУСКАЕШЬ \nНУ МДАААА \nНИКИТА \n😐 \nУ меня вопрос \n\n Ты:😳 \n\n Собеседник:В питер да \n\n',
#   'response': 'Аге \n'},
#  {'context': ' Собеседник:ТАКУЮ АВАТАРКУ УПУСКАЕШЬ \nНУ МДАААА \nНИКИТА \n😐 \nУ меня вопрос \n\n Ты:😳 \n\n Собеседник:В питер да \n\n Ты:Аге \n\n Собеседник:Антона укради \n\n',
#   'response': 'Не \n'},
#  {'context': ' Собеседник:ТАКУЮ АВАТАРКУ УПУСКАЕШЬ \nНУ МДАААА \nНИКИТА \n😐 \nУ меня вопрос \n\n Ты:😳 \n\n Собеседник:В питер да \n\n Ты:Аге \n\n Собеседник:Антона укради \n\n Ты:Не \n\n Собеседник:Почему \n\n',
#   'response': 'Он в екб \n'},
#  {'context': ' Собеседник:ТАКУЮ АВАТАРКУ УПУСКАЕШЬ \nНУ МДАААА \nНИКИТА \n😐 \nУ меня вопрос \n\n Ты:😳 \n\n Собеседник:В питер да \n\n Ты:Аге \n\n Собеседник:Антона укради \n\n Ты:Не \n\n Собеседник:Почему \n\n Ты:Он в екб \n\n Собеседник:Так вот укради \nА ты када едешь \nА мы встретимся?? \nА где ты будешь \nА что когда \nПочему мне ничу не рассказал \nА мне интересна \n\n',
#   'response': 'Я только позавчера узнал, что в Питер \nЯ в Мск хотел \nИли Питер \nВ итоге вот \nЯ завтра выезжаю на поезде \n'},
#  {'context': ' Собеседник:А где учиться будешь \n\n', 'response': 'ВШЭ \n'},
#  {'context': ' Собеседник:А где учиться будешь \n\n Ты:ВШЭ \n\n Собеседник:Какая спец \n\n',
#   'response': 'На Герасимовской обсчага \nФизика \n'},
#  {'context': ' Собеседник:А где учиться будешь \n\n Ты:ВШЭ \n\n Собеседник:Какая спец \n\n Ты:На Герасимовской обсчага \nФизика \n\n Собеседник:Вшэ ох удачи \nАхаха это где \n\n',
#   'response': 'Ну блин ты же Питерчанка \n'},
#  {'context': ' Собеседник:А где учиться будешь \n\n Ты:ВШЭ \n\n Собеседник:Какая спец \n\n Ты:На Герасимовской обсчага \nФизика \n\n Собеседник:Вшэ ох удачи \nАхаха это где \n\n Ты:Ну блин ты же Питерчанка \n\n Собеседник:Емае \nЕИАЕ \n\n',
#   'response': 'Го \n'},
#  {'context': ' Собеседник:ПХПХПХ \nХотя не \nНорм \nЯ поняла где что \n\n',
#   'response': '🤤 \n'},
#  {'context': ' Собеседник:ПХПХПХ \nХотя не \nНорм \nЯ поняла где что \n\n Ты:🤤 \n\n Собеседник:а что вы все там живете? \n\n',
#   'response': 'Там норм ? \n'},
#  {'context': ' Собеседник:ПХПХПХ \nХотя не \nНорм \nЯ поняла где что \n\n Ты:🤤 \n\n Собеседник:а что вы все там живете? \n\n Ты:Там норм ? \n\n Собеседник:Там недалеко Ксюша \n\n',
#   'response': 'Какая ? \n'},
#  {'context': ' Собеседник:ПХПХПХ \nХотя не \nНорм \nЯ поняла где что \n\n Ты:🤤 \n\n Собеседник:а что вы все там живете? \n\n Ты:Там норм ? \n\n Собеседник:Там недалеко Ксюша \n\n Ты:Какая ? \n\n Собеседник:НАША КСЮША \nщас узнаю \nПечерских \n\n',
#   'response': 'Кул \nОна тоже в СПб будет учитсья ? \n'},
#  {'context': ' Собеседник:Ну она тут живет \nТак что думаю да? \n\n',
#   'response': 'Хмм \n'},
#  {'context': ' Собеседник:Ну она тут живет \nТак что думаю да? \n\n Ты:Хмм \n\n Собеседник:Я не спрашивала ещё у неё, поступила она куда хотела или нет \n\n',
#   'response': 'Она же в аоаоао каком-то городе \nБыла \nДругом \n'},
#  {'context': ' Собеседник:Ну она тут живет \nТак что думаю да? \n\n Ты:Хмм \n\n Собеседник:Я не спрашивала ещё у неё, поступила она куда хотела или нет \n\n Ты:Она же в аоаоао каком-то городе \nБыла \nДругом \n\n Собеседник:Она летом переехала сюда \n\n',
#   'response': 'Понятно \n'},
#  {'context': ' Собеседник:Вот так \nНу конеяно крута, шо увидимся \nУу \n🙂 \nТолько Антона почему никто не украл??? \nНу вроде как норм \n\n',
#   'response': 'Слрян \nВлвдв \nИнктв \nИнета \nНет \nСорян \nПозже напишу \n'},
#  {'context': ' Собеседник:Оке \n\n',
#   'response': 'Оке \nПоявился \nУ него спрашивай 😳 \n'},
#  {'context': ' Собеседник:Оке \n\n Ты:Оке \nПоявился \nУ него спрашивай 😳 \n\n Собеседник:😐 \nТы где \nУ тебя др? \n\n',
#   'response': 'Получается да \n'},
#  {'context': ' Собеседник:Оке \n\n Ты:Оке \nПоявился \nУ него спрашивай 😳 \n\n Собеседник:😐 \nТы где \nУ тебя др? \n\n Ты:Получается да \n\n Собеседник:Ого!!! Привет \nС ДНЁМ РОЖДЕНИИЯЯ БРАТ \n😎 \n\n',
#   'response': '❤️ \n'},
#  {'context': ' Собеседник:Оке \n\n Ты:Оке \nПоявился \nУ него спрашивай 😳 \n\n Собеседник:😐 \nТы где \nУ тебя др? \n\n Ты:Получается да \n\n Собеседник:Ого!!! Привет \nС ДНЁМ РОЖДЕНИИЯЯ БРАТ \n😎 \n\n Ты:❤️ \n\n Собеседник:😵 \nТак ты где? \nВыглядит прикольно \nКогда гулять брат \n\n',
#   'response': 'Ага \nХз, когда родители ливнут \nДомой \n'},
#  {'context': ' Собеседник:Ну я жду \n🙂 \n\n', 'response': '😎 \n'},
#  {'context': ' Собеседник:👌 \n🤨 \n🤨 \n🤨 \nБрат \nТы чего \nПро меня забыл?!!!!!! \n\n',
#   'response': '👀 \n'},
#  {'context': ' Собеседник:👌 \n🤨 \n🤨 \n🤨 \nБрат \nТы чего \nПро меня забыл?!!!!!! \n\n Ты:👀 \n\n Собеседник:Так что?( \nКогда встретимся \n\n',
#   'response': 'когда у меня будет свободное время ... \n'},
#  {'context': ' Собеседник:👌 \n🤨 \n🤨 \n🤨 \nБрат \nТы чего \nПро меня забыл?!!!!!! \n\n Ты:👀 \n\n Собеседник:Так что?( \nКогда встретимся \n\n Ты:когда у меня будет свободное время ... \n\n Собеседник:🤨 \n😐 \n\n',
#   'response': 'то есть \n'},
#  {'context': ' Собеседник:👌 \n🤨 \n🤨 \n🤨 \nБрат \nТы чего \nПро меня забыл?!!!!!! \n\n Ты:👀 \n\n Собеседник:Так что?( \nКогда встретимся \n\n Ты:когда у меня будет свободное время ... \n\n Собеседник:🤨 \n😐 \n\n Ты:то есть \n\n Собеседник:Найди его 😡 \n\n',
#   'response': 'не скоро \n'},
#  {'context': ' Собеседник:😐 \n\n',
#   'response': 'я ни разу еще не гулял в центре ... \nу нас бля 4 сесси \nсаси \n'},
#  {'context': ' Собеседник:😐 \n\n Ты:я ни разу еще не гулял в центре ... \nу нас бля 4 сесси \nсаси \n\n Собеседник:Если найдёшь часика два, погуляешь 😡 \n\n',
#   'response': 'мне ехать 2 часика :) \n'},
#  {'context': ' Собеседник:😐 \n\n Ты:я ни разу еще не гулял в центре ... \nу нас бля 4 сесси \nсаси \n\n Собеседник:Если найдёшь часика два, погуляешь 😡 \n\n Ты:мне ехать 2 часика :) \n\n Собеседник:До куда \n\n',
#   'response': 'погуляю, кончено \nдо невского \n'},
#  {'context': ' Собеседник:Со мной \n\n',
#   'response': 'да \nа ты кст где живешь ? \n'},
#  {'context': ' Собеседник:Со мной \n\n Ты:да \nа ты кст где живешь ? \n\n Собеседник:Да ну, там меньше ехать, уакие два часа \nЯ говорила \n\n',
#   'response': '3 года назад ? \n'},
#  {'context': ' Собеседник:Со мной \n\n Ты:да \nа ты кст где живешь ? \n\n Собеседник:Да ну, там меньше ехать, уакие два часа \nЯ говорила \n\n Ты:3 года назад ? \n\n Собеседник:Нет недавно же \n\n',
#   'response': 'или недавно \nаоа \n'},
#  {'context': ' Собеседник:Со мной \n\n Ты:да \nа ты кст где живешь ? \n\n Собеседник:Да ну, там меньше ехать, уакие два часа \nЯ говорила \n\n Ты:3 года назад ? \n\n Собеседник:Нет недавно же \n\n Ты:или недавно \nаоа \n\n Собеседник:Кароч на другой конце красной ветки \nНо мне ещё доехать надо до метро \n\n',
#   'response': 'ну назови улицу блажаюзую \n'},
#  {'context': ' Собеседник:Ленинский \n\n', 'response': 'За Кадом ? \nтаак \n'},
#  {'context': ' Собеседник:Ленинский \n\n Ты:За Кадом ? \nтаак \n\n Собеседник:Нет хд \n\n',
#   'response': 'у вас на выходе с метро тц ? \nнет да ? \n'},
#  {'context': ' Собеседник:Ленинский \n\n Ты:За Кадом ? \nтаак \n\n Собеседник:Нет хд \n\n Ты:у вас на выходе с метро тц ? \nнет да ? \n\n Собеседник:Да \nЦелых два \nФранцузский бульвар и Нарва \nНо это не за кадом \n\n',
#   'response': 'ок \nкрч \nвот как только появляетс явремя \nгулять идем \nно появится оно я хз когда \n'},
#  {'context': ' Собеседник:Я тебя кажды день доставать будет \n\n',
#   'response': 'я в старый добрый ЧС кину хпхпхп \nвсе пока я пошел делать алгебру аоаоаоаоа \n'},
#  {'context': ' Собеседник:Я тебя кажды день доставать будет \n\n Ты:я в старый добрый ЧС кину хпхпхп \nвсе пока я пошел делать алгебру аоаоаоаоа \n\n Собеседник:Ээээ🥺 \nУдачки \n\n',
#   'response': '😎 \n'},
#  {'context': ' Собеседник:Я обиделась !! \n😭 \n\n', 'response': '😭 \n'},
#  {'context': ' Собеседник:Я обиделась !! \n😭 \n\n Ты:😭 \n\n Собеседник:Ого, Никита емае \n\n',
#   'response': 'Ого, привет \n'},
#  {'context': ' Собеседник:В моздоке? \n\n', 'response': 'Yes :( \n'},
#  {'context': ' Собеседник:И все это время занят был? \n\n',
#   'response': '👍 \nПочему-то у некоторых людей очень пессемистичное отношение к Питеру \nМне типо говорили: "о, Питер, постоянные дожди", "давящая атмосфера" и т.п. \nМне за эти 5 месяцев очень понравился этот город \n(хотя, в центре нормально я гулял только 1 раз...) \n(И, наверное, после Моздока любой город очень понравится :)) \n'},
#  {'context': ' Собеседник:Ну климат и правда может такой себе, но почему это должно мешать гулять \nТолько если холод \n\n',
#   'response': 'Мне нравится такой климат \n'},
#  {'context': ' Собеседник:Ну климат и правда может такой себе, но почему это должно мешать гулять \nТолько если холод \n\n Ты:Мне нравится такой климат \n\n Собеседник:Везёт \n\n',
#   'response': 'Я люблю дождь :) \nВозможно, я слишком мало жил в Питере и он мне скоро надоест \n'},
#  {'context': ' Собеседник:Мне не особо, у меня голова часто болит из-за погоды, и я болею ещё посточнно( может тоже этого) \nЯ недавно была в другом городе \nГде влажность другая \nОфигеть, оказывается в -2 можно гулять в кофте почти \nКогда в Питере я умираю хдд \nИ чувствовала себя лучше как то \nТак что я в будущем мб перееду, не знаю куда \nПитер сам мне нравится , да и погода особо не мешает \nНо это такое \nНу там ветра не было \nИ влажность не такая как у нас \nИ я на катке каталась в кофте и тепло хдд \nУ меня тут сильный ветер частооо \n( я у залива тут живу ) \n\n',
#   'response': 'Город "Апапрвапр" город, в которй ты недавно ездила \nЯ забыл \n'},
#  {'context': ' Собеседник:Весьегонск я ездила \nДеревня \nПочти хд \n\n',
#   'response': 'Переезжай на Герасимовскую 13 \nВаще топ \nСтолько всего интересного вокруг \n'},
#  {'context': ' Собеседник:Весьегонск я ездила \nДеревня \nПочти хд \n\n Ты:Переезжай на Герасимовскую 13 \nВаще топ \nСтолько всего интересного вокруг \n\n Собеседник:Я люблю свой район \nНо бываю там на площади Ленина умираю \n\n',
#   'response': 'Недавно, например, мужик какоц-то спрыгнул с окна :) \n'},
#  {'context': ' Собеседник:Ой, да такое везде хдд \nЯ кстати говорю только о косметике \nИ мб ещё о фотках , но это редко \nТы же меня там по пути не потеряешь специально? \n\n',
#   'response': 'Зачем мне специально терять тебя 😳 \nЗвучит интересно \nЯ о ней ничего не знаю, поэтому расскажешь все \n'},
#  {'context': ' Собеседник:Надоем хдд \n\n',
#   'response': 'Ну, скорее я \nТебе надоем \n'},
#  {'context': ' Собеседник:Надоем хдд \n\n Ты:Ну, скорее я \nТебе надоем \n\n Собеседник:Та нее \n\n',
#   'response': 'Вспомним лихие 2017 -ые \n'},
#  {'context': ' Собеседник:Надоем хдд \n\n Ты:Ну, скорее я \nТебе надоем \n\n Собеседник:Та нее \n\n Ты:Вспомним лихие 2017 -ые \n\n Собеседник:Сейчас все так поменялось \nУжас \n\n',
#   'response': 'Хах, в каком плане? \n'},
#  {'context': ' Собеседник:Надоем хдд \n\n Ты:Ну, скорее я \nТебе надоем \n\n Собеседник:Та нее \n\n Ты:Вспомним лихие 2017 -ые \n\n Собеседник:Сейчас все так поменялось \nУжас \n\n Ты:Хах, в каком плане? \n\n Собеседник:Ну я вот да \n\n',
#   'response': 'Что ты подразумеваешь под «все»? \n'},
#  {'context': ' Собеседник:Изменилась \n\n',
#   'response': 'Ну мы все изменились :) \n'},
#  {'context': ' Собеседник:Изменилась \n\n Ты:Ну мы все изменились :) \n\n Собеседник:Вот я и говорю \n🥺 \n\n',
#   'response': 'Новая Маша которая не шутит про хуи 😳 \nИ не посылает нахуй \n😞 \n'},
#  {'context': ' Собеседник:Изменилась \n\n Ты:Ну мы все изменились :) \n\n Собеседник:Вот я и говорю \n🥺 \n\n Ты:Новая Маша которая не шутит про хуи 😳 \nИ не посылает нахуй \n😞 \n\n Собеседник:Я и раньше не шутила 😳 \n\n',
#   'response': 'Ну ладно, поверю \n'},
#  {'context': ' Собеседник:Посылаю плохих бук \n\n',
#   'response': 'Ого, старославянский \n🙃 \n'},
#  {'context': ' Собеседник:Посылаю плохих бук \n\n Ты:Ого, старославянский \n🙃 \n\n Собеседник:🤕 \nСтикеры до сих пор люблю \nТы мой рисунок удалил ? \n\n',
#   'response': 'Малюююсенький \n'},
#  {'context': ' Собеседник:Посылаю плохих бук \n\n Ты:Ого, старославянский \n🙃 \n\n Собеседник:🤕 \nСтикеры до сих пор люблю \nТы мой рисунок удалил ? \n\n Ты:Малюююсенький \n\n Собеседник:Мур там написано \n\n',
#   'response': 'Как такое удалить \nДа, конечно \nАхахах \n😱 \n'},
#  {'context': ' Собеседник:Не могу найти \nА когда гулять \nСейчас последние два дня хорошая погода \nТак я тебе тут и писала хд \n\n',
#   'response': 'У меня уведомления ток на whatsapp \nСмари \nЯ прилетаю завтра в 3 \nГо послезавтра \n'},
#  {'context': ' Собеседник:Не могу найти \nА когда гулять \nСейчас последние два дня хорошая погода \nТак я тебе тут и писала хд \n\n Ты:У меня уведомления ток на whatsapp \nСмари \nЯ прилетаю завтра в 3 \nГо послезавтра \n\n Собеседник:Окей!! \n🎉 \n\n',
#   'response': 'А куда идем \n🙃 \n'},
#  {'context': ' Собеседник:Забыл ? \n\n',
#   'response': 'Где втричаемса \nзабыл да \n'},
#  {'context': ' Собеседник:Забыл ? \n\n Ты:Где втричаемса \nзабыл да \n\n Собеседник:Можно у метро адмиралтейская \n\n',
#   'response': 'Ага \n'},
#  {'context': ' Собеседник:Забыл ? \n\n Ты:Где втричаемса \nзабыл да \n\n Собеседник:Можно у метро адмиралтейская \n\n Ты:Ага \n\n Собеседник:А ты у какой станции метро живешь \n\n',
#   'response': 'Дальше куды \nахахха \nахаха \nахах \nстанция метро \nхаха \n1 час от меня до станции метро .... \n'},
#  {'context': ' Собеседник:Я тоже не у метро))))) \nНу я про то что ближе всего \n\n',
#   'response': 'Ну, ближе Лесная \n'},
#  {'context': ' Собеседник:Я тоже не у метро))))) \nНу я про то что ближе всего \n\n Ты:Ну, ближе Лесная \n\n Собеседник:Так что для меня это уже не смешно, это моя жизнь.. \n\n',
#   'response': 'Ну мы крч встретимся \nкуды потом а а а а \nа \n'},
#  {'context': ' Собеседник:На дворцовую можно сходить а от туда до новой Голландии дойти \nПешочком \nСпешел фор ю не тц \n\n',
#   'response': 'Оке \n👌 \n'},
#  {'context': ' Собеседник:На дворцовую можно сходить а от туда до новой Голландии дойти \nПешочком \nСпешел фор ю не тц \n\n Ты:Оке \n👌 \n\n Собеседник:Уххх пешочком гулять \n\n',
#   'response': 'Что так ? \nНастоящие питербуржцы на электросамокатах ? \n'},
#  {'context': ' Собеседник:Обычно я дома \nЭто думаю москвичи так \n\n',
#   'response': 'Ухх, у меня будет неделя ходьбы \nПо Питеру \nпока, ноги \nКстати, во скок пойдем ? \n'},
#  {'context': ' Собеседник:Обычно я дома \nЭто думаю москвичи так \n\n Ты:Ухх, у меня будет неделя ходьбы \nПо Питеру \nпока, ноги \nКстати, во скок пойдем ? \n\n Собеседник:Ну.. во сколько тебе удобно? \n\n',
#   'response': 'в любое время \nя всю неделю свободен \nтебе во сколько удобно ? \nгоу \n'},
#  {'context': ' Собеседник:Главное не проспать )) \n\n',
#   'response': 'тычо до 2 спишь *_* \n'},
#  {'context': ' Собеседник:Главное не проспать )) \n\n Ты:тычо до 2 спишь *_* \n\n Собеседник:😐 \nДо вечера \n\n',
#   'response': 'или в 2 ночи \n'},
#  {'context': ' Собеседник:Главное не проспать )) \n\n Ты:тычо до 2 спишь *_* \n\n Собеседник:😐 \nДо вечера \n\n Ты:или в 2 ночи \n\n Собеседник:Я ложусь утром спать) \n😺 \nЗачем он на котика орет \n😐 \n😶 \n\n',
#   'response': '😒 \n'},
#  {'context': ' Собеседник:Главное не проспать )) \n\n Ты:тычо до 2 спишь *_* \n\n Собеседник:😐 \nДо вечера \n\n Ты:или в 2 ночи \n\n Собеседник:Я ложусь утром спать) \n😺 \nЗачем он на котика орет \n😐 \n😶 \n\n Ты:😒 \n\n Собеседник:Хотя боюсь мы не сможем в центре погулять \nИбо завтра большая вероятность люди выходить будут \nМб и после завтра \n😐 \nСейчас уже выходят \nНу люди идут на митинг \n\n',
#   'response': '🤬 \n'},
#  {'context': ' Собеседник:Сложно \n\n',
#   'response': 'Ну ничо \nПогуляем с людьми :) \n'},
#  {'context': ' Собеседник:Сложно \n\n Ты:Ну ничо \nПогуляем с людьми :) \n\n Собеседник:Ахах \n\n',
#   'response': 'И тебя забанят в унике :) \n'},
#  {'context': ' Собеседник:Сложно \n\n Ты:Ну ничо \nПогуляем с людьми :) \n\n Собеседник:Ахах \n\n Ты:И тебя забанят в унике :) \n\n Собеседник:Тебе есть 18? Хд \nИзвини ) \nВ августе исполнилось да \n\n',
#   'response': 'Мне 12 \nПошлый \n'},
#  {'context': ' Собеседник:Сложно \n\n Ты:Ну ничо \nПогуляем с людьми :) \n\n Собеседник:Ахах \n\n Ты:И тебя забанят в унике :) \n\n Собеседник:Тебе есть 18? Хд \nИзвини ) \nВ августе исполнилось да \n\n Ты:Мне 12 \nПошлый \n\n Собеседник:Ок \n\n',
#   'response': 'Ты не помнишь? \n'},
#  {'context': ' Собеседник:Помню \n\n', 'response': 'Yes 😎 \n'},
#  {'context': ' Собеседник:Помню \n\n Ты:Yes 😎 \n\n Собеседник:Тебе 12 исполнилось в августа \n\n',
#   'response': 'Восенацать \nМогу на meeting ходить \n'},
#  {'context': ' Собеседник:Помню \n\n Ты:Yes 😎 \n\n Собеседник:Тебе 12 исполнилось в августа \n\n Ты:Восенацать \nМогу на meeting ходить \n\n Собеседник:Круто \n\n',
#   'response': 'Подожди, а тебе 😳 ? \nЕсть \n'},
#  {'context': ' Собеседник:Помню \n\n Ты:Yes 😎 \n\n Собеседник:Тебе 12 исполнилось в августа \n\n Ты:Восенацать \nМогу на meeting ходить \n\n Собеседник:Круто \n\n Ты:Подожди, а тебе 😳 ? \nЕсть \n\n Собеседник:Я старая \n💔 \n\n',
#   'response': 'Ого, тебе 19 \n'},
#  {'context': ' Собеседник:Хд \n\n',
#   'response': 'Ну, я со старухами не гуляю, соре \n'},
#  {'context': ' Собеседник:Хд \n\n Ты:Ну, я со старухами не гуляю, соре \n\n Собеседник:А я не старуха 😡 \n🤕 \n\n',
#   'response': '🤚 \n'},
#  {'context': ' Собеседник:Хд \n\n Ты:Ну, я со старухами не гуляю, соре \n\n Собеседник:А я не старуха 😡 \n🤕 \n\n Ты:🤚 \n\n Собеседник:Короче может быть не пойдём на дворцовую, явно все перекрыто будет, мб сразу у голландии \nНу я дома буду, подумаю , куда можно пойти погулять \n\n',
#   'response': 'Oke \n'},
#  {'context': ' Собеседник:А ты купишь чипсы?? \n🤕 \n\n',
#   'response': '👌 \nТэк, мы встречаемся на Адмиралтейской в 2 часа ? \nПланы не поменялись ? \n😶 \nМожет сразу встретимся на Новой Голландии ? 🤓 \nКст, какие ? \n'},
#  {'context': ' Собеседник:А ты купишь чипсы?? \n🤕 \n\n Ты:👌 \nТэк, мы встречаемся на Адмиралтейской в 2 часа ? \nПланы не поменялись ? \n😶 \nМожет сразу встретимся на Новой Голландии ? 🤓 \nКст, какие ? \n\n Собеседник:Лейс в голубой упаковке \nПоч не на Адмиралтейской \nДоброе утро \nВсе равно, как я поняла ближайшее метро адмиралтейсткая \n\n',
#   'response': 'Dobroe \nMorning \nОк \n'},
#  {'context': ' Собеседник:😶 \n\n', 'response': 'Мне доки нужно забрать \n'},
#  {'context': ' Собеседник:😶 \n\n Ты:Мне доки нужно забрать \n\n Собеседник:Сложно \n\n',
#   'response': 'Сча \n👌 на адмиралтейской го \n'},
#  {'context': ' Собеседник:😶 \n\n Ты:Мне доки нужно забрать \n\n Собеседник:Сложно \n\n Ты:Сча \n👌 на адмиралтейской го \n\n Собеседник:Где ты учишься \n\n',
#   'response': 'Кантемировская 3 \n'},
#  {'context': ' Собеседник:😶 \n\n Ты:Мне доки нужно забрать \n\n Собеседник:Сложно \n\n Ты:Сча \n👌 на адмиралтейской го \n\n Собеседник:Где ты учишься \n\n Ты:Кантемировская 3 \n\n Собеседник:Я про учебное заведение \n\n',
#   'response': 'ВШЭ \n'},
#  {'context': ' Собеседник:😶 \n\n Ты:Мне доки нужно забрать \n\n Собеседник:Сложно \n\n Ты:Сча \n👌 на адмиралтейской го \n\n Собеседник:Где ты учишься \n\n Ты:Кантемировская 3 \n\n Собеседник:Я про учебное заведение \n\n Ты:ВШЭ \n\n Собеседник:Спасибо \n\n',
#   'response': '🙃 \nПиздец \nХолодно \n'},
#  {'context': ' Собеседник:Папа хотел узнать \n\n', 'response': '👀 \n'},
#  {'context': ' Собеседник:Папа хотел узнать \n\n Ты:👀 \n\n Собеседник:Мама решила все рассказать что я иду гулять с тобой \n\n',
#   'response': '🤚 \n-10 Карл \nХолодно \nХолодно \nХолодно \nВ холодно \n'},
#  {'context': ' Собеседник:Папа хотел узнать \n\n Ты:👀 \n\n Собеседник:Мама решила все рассказать что я иду гулять с тобой \n\n Ты:🤚 \n-10 Карл \nХолодно \nХолодно \nХолодно \nВ холодно \n\n Собеседник:Лето \n\n',
#   'response': 'Холодно \n'},
#  {'context': ' Собеседник:Папа хотел узнать \n\n Ты:👀 \n\n Собеседник:Мама решила все рассказать что я иду гулять с тобой \n\n Ты:🤚 \n-10 Карл \nХолодно \nХолодно \nХолодно \nВ холодно \n\n Собеседник:Лето \n\n Ты:Холодно \n\n Собеседник:Жара \n\n',
#   'response': 'Холодно \nЯ с юга \nВ жизни такого холода не видел \n'},
#  {'context': ' Собеседник:-12 блин \n\n',
#   'response': 'У нас зимы ваще почти не было \n'},
#  {'context': ' Собеседник:-12 блин \n\n Ты:У нас зимы ваще почти не было \n\n Собеседник:Это типо? Тёплую куртку надевать ??? \n\n',
#   'response': 'Чо \n'},
#  {'context': ' Собеседник:-12 блин \n\n Ты:У нас зимы ваще почти не было \n\n Собеседник:Это типо? Тёплую куртку надевать ??? \n\n Ты:Чо \n\n Собеседник:Ну холодно надо тёплую куртку \n\n',
#   'response': 'Ага \nЛогично \n'},
#  {'context': ' Собеседник:-12 блин \n\n Ты:У нас зимы ваще почти не было \n\n Собеседник:Это типо? Тёплую куртку надевать ??? \n\n Ты:Чо \n\n Собеседник:Ну холодно надо тёплую куртку \n\n Ты:Ага \nЛогично \n\n Собеседник:А я на пальто недавно перешла ... \n😐 \n\n',
#   'response': '😱 \n'},
#  {'context': ' Собеседник:Пипец 12 часов дня, а кое кто спит \n😐 \n\n',
#   'response': 'Kto ? \n'},
#  {'context': ' Собеседник:Пипец 12 часов дня, а кое кто спит \n😐 \n\n Ты:Kto ? \n\n Собеседник:Влад и Катя... \nКатю щас разбужу \n\n',
#   'response': 'Budi \n'},
#  {'context': ' Собеседник:Пипец 12 часов дня, а кое кто спит \n😐 \n\n Ты:Kto ? \n\n Собеседник:Влад и Катя... \nКатю щас разбужу \n\n Ты:Budi \n\n Собеседник:Мне к ней зайти надо просто \nА Влад учебу проспал \nУжас утром просыпаться \nУ тебя повербанк есть? \n\n',
#   'response': 'Da \n'},
#  {'context': ' Собеседник:Круто! Если что поделишься? Хд \n\n',
#   'response': 'Yes \n'},
#  {'context': ' Собеседник:Круто! Если что поделишься? Хд \n\n Ты:Yes \n\n Собеседник:А чего так светло на улице \n\n',
#   'response': 'XZ \n'},
#  {'context': ' Собеседник:Круто! Если что поделишься? Хд \n\n Ты:Yes \n\n Собеседник:А чего так светло на улице \n\n Ты:XZ \n\n Собеседник:Знаешь так не хочется из тепла уходить \n\n',
#   'response': '🤤 \n'},
#  {'context': ' Собеседник:Круто! Если что поделишься? Хд \n\n Ты:Yes \n\n Собеседник:А чего так светло на улице \n\n Ты:XZ \n\n Собеседник:Знаешь так не хочется из тепла уходить \n\n Ты:🤤 \n\n Собеседник:Спорт это жизнь \nЩас до троллейбуса бежала \nЯ не слышу \nЧто ты говоришь \nПоняла что ты сказал \nНуда \n\n',
#   'response': 'Не слышно 😳 \n'},
#  {'context': ' Собеседник:Мне в метро ехать минут 40 \nЯ в метро \n\n',
#   'response': 'Походу тебе придётся меня ждать 😳 \n'},
#  {'context': ' Собеседник:Мне в метро ехать минут 40 \nЯ в метро \n\n Ты:Походу тебе придётся меня ждать 😳 \n\n Собеседник:А насколько опоздаешь \nЛяя \nВремя рассчитывать не умеешь? Хд \nТы не вышел? \n\n',
#   'response': 'Я думал, сейчас 12:00 😳 \n'},
#  {'context': ' Собеседник:Ахахах..)) \n\n',
#   'response': 'Надеюсь, ты тепло оделась \nИ не замёрзнешь \n😴 \nА вообще да \nНе умею \n'},
#  {'context': ' Собеседник:Ахахах..)) \n\n Ты:Надеюсь, ты тепло оделась \nИ не замёрзнешь \n😴 \nА вообще да \nНе умею \n\n Собеседник:Ты там как ахахах \n\n',
#   'response': 'Я с села блин приехал \n'},
#  {'context': ' Собеседник:Ахахах..)) \n\n Ты:Надеюсь, ты тепло оделась \nИ не замёрзнешь \n😴 \nА вообще да \nНе умею \n\n Собеседник:Ты там как ахахах \n\n Ты:Я с села блин приехал \n\n Собеседник:Ххахахаха щас же весна \n\n',
#   'response': 'К нас весь город за 30 минут объехать можно \n'},
#  {'context': ' Собеседник:Я оделась как летом \nНаучишься думаю \nТы смотри заранее время хд \n\n',
#   'response': 'Ну я смотрю \n'},
#  {'context': ' Собеседник:Я оделась как летом \nНаучишься думаю \nТы смотри заранее время хд \n\n Ты:Ну я смотрю \n\n Собеседник:Ты хоть вышел? \nОбратно ехать на метро по пути кстати \nПо идее.. \n\n',
#   'response': 'Да я в автобусе давно уже еду \n'},
#  {'context': ' Собеседник:Тогда ок \nА куда ты там едешь \n\n',
#   'response': 'До метро \n'},
#  {'context': ' Собеседник:Тогда ок \nА куда ты там едешь \n\n Ты:До метро \n\n Собеседник:Что за троллейбус там в конце \nЯ про скрин \nЯ в метро ааа \n\n',
#   'response': 'Соре \n'},
#  {'context': ' Собеседник:Тогда ок \nА куда ты там едешь \n\n Ты:До метро \n\n Собеседник:Что за троллейбус там в конце \nЯ про скрин \nЯ в метро ааа \n\n Ты:Соре \n\n Собеседник:Щас\nПослушаю \nТы ещё в уник щас? \n😐 \nЭто какая станция \n\n',
#   'response': 'Ннее \nЯ хотел в уник зайти \nНо не зайду \nСразу поеду на адмиралтейскую \nТебе 20 минут ждать :) \n'},
#  {'context': ' Собеседник:Так \nСкажи лучше где ты \nПросто может мне просто навстречу поехать в метро \n\n',
#   'response': 'Зочем 😳 \n'},
#  {'context': ' Собеседник:Так \nСкажи лучше где ты \nПросто может мне просто навстречу поехать в метро \n\n Ты:Зочем 😳 \n\n Собеседник:Ну короче рядом \nПотому что я на Пушкинской)))))))) \nЯ тоже так то время рассчитывать не умею и выходу раньше \nЕсли я перейду на фиол след будет адмиралтейская \n\n',
#   'response': 'Ну ето не рядом \n'},
#  {'context': ' Собеседник:Ты через сколько в метро будкшь \nЯ про лесную \nЕсли что \n\n',
#   'response': 'Da \n'},
#  {'context': ' Собеседник:Ты через сколько в метро будкшь \nЯ про лесную \nЕсли что \n\n Ты:Da \n\n Собеседник:Через 21 минуту? \n\n',
#   'response': 'Через 21 на лесной \n'},
#  {'context': ' Собеседник:Ты через сколько в метро будкшь \nЯ про лесную \nЕсли что \n\n Ты:Da \n\n Собеседник:Через 21 минуту? \n\n Ты:Через 21 на лесной \n\n Собеседник:Я Кароч еду в твою сторону на метро \n\n',
#   'response': 'Ну го на Лесную :) \n'},
#  {'context': ' Собеседник:Мне мужчина место уступил \nЯ что рял старая? \n\n',
#   'response': 'Походу \n'},
#  {'context': ' Собеседник:Мне мужчина место уступил \nЯ что рял старая? \n\n Ты:Походу \n\n Собеседник:Блин \n\n',
#   'response': '😞 \n'},
#  {'context': ' Собеседник:Мне мужчина место уступил \nЯ что рял старая? \n\n Ты:Походу \n\n Собеседник:Блин \n\n Ты:😞 \n\n Собеседник:Я тебя боюсь \n\n',
#   'response': '😶 \n😭 \nБля \n'},
#  {'context': ' Собеседник:Мне мужчина место уступил \nЯ что рял старая? \n\n Ты:Походу \n\n Собеседник:Блин \n\n Ты:😞 \n\n Собеседник:Я тебя боюсь \n\n Ты:😶 \n😭 \nБля \n\n Собеседник:Шо \n\n',
#   'response': 'Я чуть не пропустил остановку \n'},
#  {'context': ' Собеседник:Мне мужчина место уступил \nЯ что рял старая? \n\n Ты:Походу \n\n Собеседник:Блин \n\n Ты:😞 \n\n Собеседник:Я тебя боюсь \n\n Ты:😶 \n😭 \nБля \n\n Собеседник:Шо \n\n Ты:Я чуть не пропустил остановку \n\n Собеседник:🤕 \nОо ты к метро идёшь?)0 \n\n',
#   'response': 'Да \nЯ в метро \n'},
#  {'context': ' Собеседник:На выборгской \nИли Ленина \n\n',
#   'response': 'Тэк \nГде встретимся \n'},
#  {'context': ' Собеседник:На выборгской \nИли Ленина \n\n Ты:Тэк \nГде встретимся \n\n Собеседник:Там выходи \nЯ щас на плодади Ленина \nУспею и до лесной думаю \nКароч еду до лесной \n😐 \nЭскалаторы в СПб это да \n\n',
#   'response': 'Жду \nНа лесной \nКак я тебя узнаю \n'},
#  {'context': ' Собеседник:Ок \nРозовая куртка яркая \n\n',
#   'response': 'Оке \nТы \nНе \nПриехала \n'},
#  {'context': ' Собеседник:Ок \nРозовая куртка яркая \n\n Ты:Оке \nТы \nНе \nПриехала \n\n Собеседник:Ахахах \nА ты \nИзвини сообщение не доходили \n\n',
#   'response': 'Я приехал \n'},
#  {'context': ' Собеседник:Ок \nРозовая куртка яркая \n\n Ты:Оке \nТы \nНе \nПриехала \n\n Собеседник:Ахахах \nА ты \nИзвини сообщение не доходили \n\n Ты:Я приехал \n\n Собеседник:Я приехала щас \n\n',
#   'response': 'Смари \nЯ на лавке \n'},
#  {'context': ' Собеседник:Ясно \nПонятно \nЧипсы хд \n\n',
#   'response': 'Хахахах \nВидимо, еще раз встретимся \nВо \nТут крч по фильтрам можешь искать \n'},
#  {'context': ' Собеседник:Ясно \nПонятно \nЧипсы хд \n\n Ты:Хахахах \nВидимо, еще раз встретимся \nВо \nТут крч по фильтрам можешь искать \n\n Собеседник:Спасибо! \n\n',
#   'response': 'А тут психологи за 500 руб \n'},
#  {'context': ' Собеседник:Ясно \nПонятно \nЧипсы хд \n\n Ты:Хахахах \nВидимо, еще раз встретимся \nВо \nТут крч по фильтрам можешь искать \n\n Собеседник:Спасибо! \n\n Ты:А тут психологи за 500 руб \n\n Собеседник:Класс , пасипа \n\n',
#   'response': '👍 \nХай \nВо скока гуляем ? \n'},
#  {'context': ' Собеседник:В часов 5 \nТы хотел на площади восстания? \n\n',
#   'response': 'Мне не принципиально :) \n'},
#  {'context': ' Собеседник:В часов 5 \nТы хотел на площади восстания? \n\n Ты:Мне не принципиально :) \n\n Собеседник:Лучше бы просто сказал да хд \n\n',
#   'response': 'Да \nХотел \nДа \nПравда \nОчень \n'},
#  {'context': ' Собеседник:В часов 5 \nТы хотел на площади восстания? \n\n Ты:Мне не принципиально :) \n\n Собеседник:Лучше бы просто сказал да хд \n\n Ты:Да \nХотел \nДа \nПравда \nОчень \n\n Собеседник:Тогда там и будем хд \n\n',
#   'response': 'Идем гулять на площадь восстания, вуху ! \n'},
#  {'context': ' Собеседник:👍 \n\n', 'response': '😁 \n'},
#  {'context': " Собеседник:И ещё я приболела, так что я наверно сегодня дома :((( \nИзвините( \n[{'type': 'mention', 'text': '@dinn_donn'}, ' если что вот ее тг'] \n\n",
#   'response': 'Ok \nВыздоравливай :) \n'},
#  {'context': " Собеседник:И ещё я приболела, так что я наверно сегодня дома :((( \nИзвините( \n[{'type': 'mention', 'text': '@dinn_donn'}, ' если что вот ее тг'] \n\n Ты:Ok \nВыздоравливай :) \n\n Собеседник:😭 \nСпасибо ( \n\n",
#   'response': '😭 \n'},
#  {'context': ' Собеседник:Мне диана сказала что не перекрывали? \n\n',
#   'response': 'Ну, когда мы гуляли уже ничего не было \nИли мы не видели ... \nВ 4 было перекрыто кста \n'},
#  {'context': ' Собеседник:блинб чипсики! хд \n\n',
#   'response': 'Хах \nМожешь забрать \nУ тебя есть час \n'},
#  {'context': ' Собеседник:блинб чипсики! хд \n\n Ты:Хах \nМожешь забрать \nУ тебя есть час \n\n Собеседник:так рано щас \nты улетаешь через час? \nБлин я бегу , пулково да? \nхдд(( \n\n',
#   'response': 'Я в 6 буду в Пулково :) \n'},
#  {'context': ' Собеседник:блинб чипсики! хд \n\n Ты:Хах \nМожешь забрать \nУ тебя есть час \n\n Собеседник:так рано щас \nты улетаешь через час? \nБлин я бегу , пулково да? \nхдд(( \n\n Ты:Я в 6 буду в Пулково :) \n\n Собеседник:пулково недалеко \nтольк о транспорт щас не ездит хд \n\n',
#   'response': '😊 \n'},
#  {'context': ' Собеседник:кстати, как погуляли тогда? \n\n',
#   'response': 'Классно \n'},
#  {'context': ' Собеседник:кстати, как погуляли тогда? \n\n Ты:Классно \n\n Собеседник:ваау, вот это ответ \n\n',
#   'response': 'Что \n'},
#  {'context': ' Собеседник:кстати, как погуляли тогда? \n\n Ты:Классно \n\n Собеседник:ваау, вот это ответ \n\n Ты:Что \n\n Собеседник:ну просто классно \nрассказывай \n\n',
#   'response': 'Классно да \nХотили гуляли, разговаривали \nА вот так я погулял :) \nТеперь меньше желания жить в Питере :( \n'},
#  {'context': ' Собеседник:у меня тоже похожие есть хдд \n\n',
#   'response': '😭 \nОстанусь в Моздоке \nЗнаешь, что я делаю ? \n'},
#  {'context': ' Собеседник:у меня тоже похожие есть хдд \n\n Ты:😭 \nОстанусь в Моздоке \nЗнаешь, что я делаю ? \n\n Собеседник:шо \n\n',
#   'response': 'Играю в Майнкрафт \n'},
#  {'context': ' Собеседник:у меня тоже похожие есть хдд \n\n Ты:😭 \nОстанусь в Моздоке \nЗнаешь, что я делаю ? \n\n Собеседник:шо \n\n Ты:Играю в Майнкрафт \n\n Собеседник:оооо \nэто круто!! \n\n',
#   'response': 'Мы с челом рубимся гы \nГо в майн \n'},
#  {'context': ' Собеседник:логично да... \n\n',
#   'response': 'Когда-нибудь ... \n'},
#  {'context': ' Собеседник:логично да... \n\n Ты:Когда-нибудь ... \n\n Собеседник:кстати мне стало лучше \nнасморк только \nи кашель какой то \nно чувствую норм \n\n',
#   'response': '🎉 \n'},
#  {'context': ' Собеседник:логично да... \n\n Ты:Когда-нибудь ... \n\n Собеседник:кстати мне стало лучше \nнасморк только \nи кашель какой то \nно чувствую норм \n\n Ты:🎉 \n\n Собеседник:если что я с человеком обычно не так грубо разговариваю, просто он немного вывел меня из себя минут 10 назад \n\n',
#   'response': 'Это ты замерзла, когда мы гуляли ? \n'},
#  {'context': ' Собеседник:не знаю, наверно я уже тогда заболевала \n\n',
#   'response': '😢 \n'},
#  {'context': ' Собеседник:не знаю, наверно я уже тогда заболевала \n\n Ты:😢 \n\n Собеседник:я в воскресенье не могла проснуться , спала до 6 вечера где-то хдд хотя вставала в 3 вроде, чтобы покушать \n\n',
#   'response': 'Да норм разговариваешь, вроде :) \n'},
#  {'context': ' Собеседник:все нормально!! \nмне кажется немного грубо просто \n\n',
#   'response': 'Грубо, если бы ты послала нахуй \n'},
#  {'context': ' Собеседник:все нормально!! \nмне кажется немного грубо просто \n\n Ты:Грубо, если бы ты послала нахуй \n\n Собеседник:мпхпхапхп \n\n',
#   'response': 'Я собрал сумки \n'},
#  {'context': ' Собеседник:все нормально!! \nмне кажется немного грубо просто \n\n Ты:Грубо, если бы ты послала нахуй \n\n Собеседник:мпхпхапхп \n\n Ты:Я собрал сумки \n\n Собеседник:так же антона пытался забграть? \nтеперь понятно почему сбежал \n\n',
#   'response': 'Аге :( \n'},
#  {'context': ' Собеседник:хдд \n\n',
#   'response': 'Ну я скотчем еще сверху замотал \n'},
#  {'context': ' Собеседник:хдд \n\n Ты:Ну я скотчем еще сверху замотал \n\n Собеседник:хдд \nблин забыла антону написат \nпочему он сбежал , хотела спросить \n\n',
#   'response': '😊 \n'},
#  {'context': ' Собеседник:🥺 \nСегодня др у Дианы помнишь? \n\n',
#   'response': 'Aoaooaa \nАоаоааоа \nПооа \nАоаоа \nОаоа \nНе помню ... \n'},
#  {'context': ' Собеседник:🥺 \nСегодня др у Дианы помнишь? \n\n Ты:Aoaooaa \nАоаоааоа \nПооа \nАоаоа \nОаоа \nНе помню ... \n\n Собеседник:Теперь помништ \n\n',
#   'response': 'Спасибо, что напомнила :) \nБлэт \nВ телеге нет напоминалок про др ... \n'},
#  {'context': ' Собеседник:Хд \n\n',
#   'response': 'Маш \nМаш \nМаш \nКак дела ? \nТы уже не болеешь ? \n👀 \n'},
#  {'context': ' Собеседник:Хд \n\n Ты:Маш \nМаш \nМаш \nКак дела ? \nТы уже не болеешь ? \n👀 \n\n Собеседник:Всм \nПривет \nНе болею почти \nВроде как \n\n',
#   'response': '👍 \n'},
#  {'context': ' Собеседник:Войсы пока что не могу \nну я явно оч общительна \nраз я не овтечала 10 дней... пипец \n\n',
#   'response': '👀 \nпрям как я \nтак вот и будем общаться \nс интервалом в 10 дней \n'},
#  {'context': ' Собеседник:Войсы пока что не могу \nну я явно оч общительна \nраз я не овтечала 10 дней... пипец \n\n Ты:👀 \nпрям как я \nтак вот и будем общаться \nс интервалом в 10 дней \n\n Собеседник:Хорошо, отвечу через 10 дней \n\n',
#   'response': 'так ты за прошлые 10 дней не ответила \n😭 \n'},
#  {'context': ' Собеседник:А ой \nНу снег это круто \nЗато шарф пригодился))) \n\n',
#   'response': '🙂 \n'},
#  {'context': ' Собеседник:Давно новых фоток у тебя в инсте не было \nЖду крч \n\n',
#   'response': 'На новую фотку \nМожешь выложить ее у себя на странице \n🙄 \n'},
#  {'context': ' Собеседник:😡 \n\n',
#   'response': 'Оксана, ты заебала, приезжай уже \n😐 \n'},
#  {'context': ' Собеседник:Кто такая Оксана \nЭто ты? \n\n',
#   'response': 'ДА \n🙃 \n'},
#  {'context': ' Собеседник:Ого новая ава \n\n',
#   'response': 'Поставь лайк \nИ подпишись \n🥺 \n'},
#  {'context': ' Собеседник:Ого новая ава \n\n Ты:Поставь лайк \nИ подпишись \n🥺 \n\n Собеседник:А почему ты скринил пхахаха \nКак это давно было... \nВхахах пипец \n\n',
#   'response': 'Я только сейчас понял, что мы знакомы с тобой столько же, сколько лет Кесси \n'},
#  {'context': ' Собеседник:Смотри , крем для тортика \nПомню ее маленькой 🥺🥺 \n\n',
#   'response': 'Вау \nТы сейчас торт делаешь 😳 \n'},
#  {'context': ' Собеседник:Смотри , крем для тортика \nПомню ее маленькой 🥺🥺 \n\n Ты:Вау \nТы сейчас торт делаешь 😳 \n\n Собеседник:Впервые делаю тортик 🥺 \nЗавтра др у Влада \n\n',
#   'response': '🙊 \nКруто \n'},
#  {'context': ' Собеседник:Смотри , крем для тортика \nПомню ее маленькой 🥺🥺 \n\n Ты:Вау \nТы сейчас торт делаешь 😳 \n\n Собеседник:Впервые делаю тортик 🥺 \nЗавтра др у Влада \n\n Ты:🙊 \nКруто \n\n Собеседник:Хы \n\n',
#   'response': 'А как должен выглядеть конечный вариант ? \nТорта \n'},
#  {'context': ' Собеседник:Я сфоткаю \nКривовато немного \nНо зато да \nСама делала хд \n\n',
#   'response': 'С душой 😳 \n'},
#  {'context': ' Собеседник:Я сфоткаю \nКривовато немного \nНо зато да \nСама делала хд \n\n Ты:С душой 😳 \n\n Собеседник:Не могу выровнить хдд \nВнутри крем чиз и бананчики \nЕщё украшать буду \n\n',
#   'response': 'Вау это пизанская башня \n'},
#  {'context': ' Собеседник:Хд \n\n', 'response': 'Я уже представил \n'},
#  {'context': ' Собеседник:Хд \n\n Ты:Я уже представил \n\n Собеседник:Аххахаха \nХОРОШАЯ ИДЕЯ \nЭто тебе такой надо делать хдд \n\n',
#   'response': 'Го 😳 \n'},
#  {'context': ' Собеседник:Вхахах... \n🌝 \nФу куришь \nАхахах поняла что не скинула как выглядел в итоге торт \nУпс \nБольше месяца делала ахахах \nИзвините \n\n',
#   'response': 'Хах, круто! \n👉 \nнет вообще \nтолько пару раз попробовал \n'},
#  {'context': ' Собеседник:Вхахах... \n🌝 \nФу куришь \nАхахах поняла что не скинула как выглядел в итоге торт \nУпс \nБольше месяца делала ахахах \nИзвините \n\n Ты:Хах, круто! \n👉 \nнет вообще \nтолько пару раз попробовал \n\n Собеседник:Уу \n\n',
#   'response': 'не советую \n'},
#  {'context': ' Собеседник:Я пробовала \U0001f972 \n\n',
#   'response': '😯 \nи как \nуже стала курильщиком ? \n'},
#  {'context': ' Собеседник:Не круто \nНет \nНо раз в полгода бывает хочется покурить \nМне нрав электронки \nС ягодками ммм \nНо я посл раз ток на нг \nА так фу \n\n',
#   'response': '✌ \nМаша маша маша маша \nГо гулять 🥺 \n'},
#  {'context': ' Собеседник:Не круто \nНет \nНо раз в полгода бывает хочется покурить \nМне нрав электронки \nС ягодками ммм \nНо я посл раз ток на нг \nА так фу \n\n Ты:✌ \nМаша маша маша маша \nГо гулять 🥺 \n\n Собеседник:Ты в СПб?? \n\n',
#   'response': 'Ес \nНа все лето \nИ больше 😎 \n'},
#  {'context': ' Собеседник:Ооо \nЯ буду не против!! Я сейчас не а СПб ахаха \nНо недалеко \n\n',
#   'response': '😢 \n'},
#  {'context': ' Собеседник:Ооо \nЯ буду не против!! Я сейчас не а СПб ахаха \nНо недалеко \n\n Ты:😢 \n\n Собеседник:Я в лен области \nМб на след неделе!! \nКрутооо \n\n',
#   'response': 'Ладно, как будешь в спб, пиши \n😎 \n'},
#  {'context': ' Собеседник:Ооо \nЯ буду не против!! Я сейчас не а СПб ахаха \nНо недалеко \n\n Ты:😢 \n\n Собеседник:Я в лен области \nМб на след неделе!! \nКрутооо \n\n Ты:Ладно, как будешь в спб, пиши \n😎 \n\n Собеседник:🥺 \n\n',
#   'response': '☄ \n'},
#  {'context': ' Собеседник:А чего ты так рано в СПб? \n\n',
#   'response': 'А почему бы и нет :))) \n'},
#  {'context': ' Собеседник:А чего ты так рано в СПб? \n\n Ты:А почему бы и нет :))) \n\n Собеседник:Я думала ты к осени приедешь \n\n',
#   'response': 'Я уже заебался в Моздоке… \n'},
#  {'context': ' Собеседник:А чего ты так рано в СПб? \n\n Ты:А почему бы и нет :))) \n\n Собеседник:Я думала ты к осени приедешь \n\n Ты:Я уже заебался в Моздоке… \n\n Собеседник:Ааа \n\n',
#   'response': 'Упросился в общагу, меня пустили :) \n'},
#  {'context': ' Собеседник:Ооо круто \nДиане сказал, что приехал ??? \n\n',
#   'response': 'Не круто, а просто ахуенно \n'},
#  {'context': ' Собеседник:Ооо круто \nДиане сказал, что приехал ??? \n\n Ты:Не круто, а просто ахуенно \n\n Собеседник:Мы с ней недавно на концерте были \n\n',
#   'response': 'Что за концерт? \nНоу \n'},
#  {'context': ' Собеседник:Ооо круто \nДиане сказал, что приехал ??? \n\n Ты:Не круто, а просто ахуенно \n\n Собеседник:Мы с ней недавно на концерте были \n\n Ты:Что за концерт? \nНоу \n\n Собеседник:Извини, отвыкла мат говорить ахах \nКИС КИС \n\n',
#   'response': 'Кис кис кис кис \nНу, ты знаешь эту песню из тиктока 👉🏻👈🏻 \n'},
#  {'context': ' Собеседник:Наверно да \nТы что \nВ тиктоке сидишь ? \n\n',
#   'response': 'аГа вО пРиКОл \nА ты не сидишь😳 \n'},
#  {'context': ' Собеседник:Наверно да \nТы что \nВ тиктоке сидишь ? \n\n Ты:аГа вО пРиКОл \nА ты не сидишь😳 \n\n Собеседник:Сижу \nЯ же тиктокер \n\n',
#   'response': 'Ооо, крутая 😎 \n'},
#  {'context': ' Собеседник:Наверно да \nТы что \nВ тиктоке сидишь ? \n\n Ты:аГа вО пРиКОл \nА ты не сидишь😳 \n\n Собеседник:Сижу \nЯ же тиктокер \n\n Ты:Ооо, крутая 😎 \n\n Собеседник:🥺 \nРаз ты мне сказал, шо приехал \nЗначит тебе было интересно когда гуляли ??? \n\n',
#   'response': 'А, что ты думала…. \n'},
#  {'context': ' Собеседник:Не знаю \nВдруг я скучная \nХд \n\n',
#   'response': 'Хаха, боже, нет \nА вдруг я скучный 😳 \n'},
#  {'context': ' Собеседник:Не знаю \nВдруг я скучная \nХд \n\n Ты:Хаха, боже, нет \nА вдруг я скучный 😳 \n\n Собеседник:Хдд \nНет \n\n',
#   'response': '☄ \n'},
#  {'context': ' Собеседник:Не знаю \nВдруг я скучная \nХд \n\n Ты:Хаха, боже, нет \nА вдруг я скучный 😳 \n\n Собеседник:Хдд \nНет \n\n Ты:☄ \n\n Собеседник:Классные стикеры \n\n',
#   'response': 'Ну так аниме же \n'},
#  {'context': ' Собеседник:Не знаю \nВдруг я скучная \nХд \n\n Ты:Хаха, боже, нет \nА вдруг я скучный 😳 \n\n Собеседник:Хдд \nНет \n\n Ты:☄ \n\n Собеседник:Классные стикеры \n\n Ты:Ну так аниме же \n\n Собеседник:☄ \nПрив \nПривет \nПр \nИвет \n☄ \n\n',
#   'response': 'Wazup \n'},
#  {'context': ' Собеседник:Что делаешь в +34? \nЭто вторник \nАхахха \n😱 \n\n',
#   'response': '☄ \nХаха \nЕсли гулять, то только не в такую жару… \n'},
#  {'context': ' Собеседник:Что делаешь в +34? \nЭто вторник \nАхахха \n😱 \n\n Ты:☄ \nХаха \nЕсли гулять, то только не в такую жару… \n\n Собеседник:А больше некогда \nЖара всю неделю \nТам в парке 300 летия фонтпны \n\n',
#   'response': 'Через неделю  👉🏻👈🏻 \n'},
#  {'context': ' Собеседник:Утопиться можно \nОй \nНе то \nВодичка круто \n\n',
#   'response': '🤔 \n'},
#  {'context': ' Собеседник:Утопиться можно \nОй \nНе то \nВодичка круто \n\n Ты:🤔 \n\n Собеседник:Проблематично думаю через недельку, но я посмотрю \nЯ в июле уезжаю просто \n😱 \n\n',
#   'response': '😢 \nА когда приезжаешь 😢 \n'},
#  {'context': ' Собеседник:Утопиться можно \nОй \nНе то \nВодичка круто \n\n Ты:🤔 \n\n Собеседник:Проблематично думаю через недельку, но я посмотрю \nЯ в июле уезжаю просто \n😱 \n\n Ты:😢 \nА когда приезжаешь 😢 \n\n Собеседник:Ахахах \nВ августе))) и улетаю))))) \nНа др точно вернусь пхахаха \nК Антону лечу.... \n\n',
#   'response': 'Ну крч, в конце недели этой норм погода \n'},
#  {'context': ' Собеседник:😱 \n\n', 'response': 'Рили 😳 \n'},
#  {'context': ' Собеседник:😱 \n\n Ты:Рили 😳 \n\n Собеседник:Ну я до среды в городе буду на этой неделе \nЯ завтра еду в город на такси вау такси \n\n',
#   'response': '😳 \n'},
#  {'context': ' Собеседник:😱 \n\n Ты:Рили 😳 \n\n Собеседник:Ну я до среды в городе буду на этой неделе \nЯ завтра еду в город на такси вау такси \n\n Ты:😳 \n\n Собеседник:(Обратно на маршрутке в среду эту пиздец жару) \nВ екб к сестре хд \n\n',
#   'response': '😳 \nСестра Антон \n'},
#  {'context': ' Собеседник:Ну если мне подарят деняк в июле я полечу \nСестра Настя \n( мой подарок на др это полёт в екб хд) \n\n',
#   'response': 'Ахаххаха \nКрч го в следующий пн \nИли вскр \nКоторое через неделю \n'},
#  {'context': ' Собеседник:Ну если мне подарят деняк в июле я полечу \nСестра Настя \n( мой подарок на др это полёт в екб хд) \n\n Ты:Ахаххаха \nКрч го в следующий пн \nИли вскр \nКоторое через неделю \n\n Собеседник:Выходные точно нет, в понедельник думаю да \n\n',
#   'response': 'Оки \nОки \n'},
#  {'context': ' Собеседник:Хотя давай может 30 июня? \nНу Кароч 28-30 июня \nХд \n\n',
#   'response': 'Можно да \n'},
#  {'context': ' Собеседник:Хотя давай может 30 июня? \nНу Кароч 28-30 июня \nХд \n\n Ты:Можно да \n\n Собеседник:Тогда я напишу тебе! \n\n',
#   'response': 'Хорошо! \n'},
#  {'context': ' Собеседник:Хотя давай может 30 июня? \nНу Кароч 28-30 июня \nХд \n\n Ты:Можно да \n\n Собеседник:Тогда я напишу тебе! \n\n Ты:Хорошо! \n\n Собеседник:У меня просто по идее экзамен 1, поэтому я приеду в этих числах точно хд \n\n',
#   'response': 'Экзамен 😳 \nКуда ? \nГде? \n'},
#  {'context': ' Собеседник:Ну в колледж \nХд \n\n', 'response': 'Прикол \n'},
#  {'context': ' Собеседник:Что за эмо бой \nНикита не спи \nМы в среду пойдём? \nЗайдём в аниме магазин? Мне надо подарок купить \n🥺 \n\n',
#   'response': 'alt-подросток \nой, блин, Маш, я чуть не забыл, что мы гулять собрались ... \nя с удовольствием :) \nи еще я делал тест на антитела и их у меня меньше, чем 3.8, а это мало ... \nкажется, я болею в слабой степени ... \nя очень не хочу заражать тебя и других людей ... \nдавай ближе к среде я скажу точно, потому что сейчас не очень понятно \nо, это который на этажах? \n'},
#  {'context': ' Собеседник:Тогда и правда не стоит 😅 у меня щас иммунитет ослаблен очень \nЯ болею щас 😅😅 \n\n',
#   'response': 'ковидом ? \n'},
#  {'context': ' Собеседник:Тогда и правда не стоит 😅 у меня щас иммунитет ослаблен очень \nЯ болею щас 😅😅 \n\n Ты:ковидом ? \n\n Собеседник:Нет \nЯ или простудилась \nИли тепловой удар \nКароч мне хуево \nНо это уже дней 5 \n\n',
#   'response': 'ну как бы не факт, что я ковидом, но думаю, лучше не рисковать ... \n'},
#  {'context': ' Собеседник:Эх \nТогда в августе увидимся(( \n\n',
#   'response': 'обязательно!!! \nв каких числах ты пиедешь? \n'},
#  {'context': ' Собеседник:Эх \nТогда в августе увидимся(( \n\n Ты:обязательно!!! \nв каких числах ты пиедешь? \n\n Собеседник:Ну я весь июль в другом городе \nА в августе там сложно \nЯ по идее в екб ещё улетаю \nПоэтому я не знаю \n\n',
#   'response': 'ух, ну когда-нибудь точно погуляем ... \nлетом \nsame \n'},
#  {'context': ' Собеседник:О у тебя летом др \n\n',
#   'response': 'угу \nв конце лета \nбля \n'},
#  {'context': ' Собеседник:О у тебя летом др \n\n Ты:угу \nв конце лета \nбля \n\n Собеседник:Я помню \n\n',
#   'response': 'я не знаю, когда у тебя др ... \nу тебя же тоже летом \nили в мае ... было \nпрости ... \n'},
#  {'context': ' Собеседник:О у тебя летом др \n\n Ты:угу \nв конце лета \nбля \n\n Собеседник:Я помню \n\n Ты:я не знаю, когда у тебя др ... \nу тебя же тоже летом \nили в мае ... было \nпрости ... \n\n Собеседник:Хдд \nЯ запомнила потому что во первых \nОн недалеко от моего \nВо вторых не знаю \n14 августа \n\n',
#   'response': 'о, круто \n😓 \n'},
#  {'context': ' Собеседник:Тебе будет 19? \n\n',
#   'response': 'угу \nа тебеее? \nебааать \n'},
#  {'context': ' Собеседник:Тебе будет 19? \n\n Ты:угу \nа тебеее? \nебааать \n\n Собеседник:Паспорт.... \n\n',
#   'response': 'жеесть \nнам же было 14 лет когда-то \n'},
#  {'context': ' Собеседник:Тебе будет 19? \n\n Ты:угу \nа тебеее? \nебааать \n\n Собеседник:Паспорт.... \n\n Ты:жеесть \nнам же было 14 лет когда-то \n\n Собеседник:Я не думаю, что в 14 я с тобой была знакома пхахах \n\n',
#   'response': 'ну сколько там на было в 2017 \n'},
#  {'context': ' Собеседник:15 мне было ахах \n\n', 'response': 'хахах да \n'},
#  {'context': ' Собеседник:15 мне было ахах \n\n Ты:хахах да \n\n Собеседник:Маленький \n\n',
#   'response': '🙁 \n'},
#  {'context': ' Собеседник:Привет \nВчера забыла написать, весь день спала \nХоть ты меня и не поздравлял \nНо с прошедшим днём рождения :)) \n\n',
#   'response': 'привет \nспасибо!!! \n😔 \n'},
#  {'context': '', 'response': '👀 \n'},
#  {'context': ' Ты:👀 \n\n Собеседник:🌟 \n\n',
#   'response': 'Фух, нормальная телега \nА не лагающий nekto me \n'},
#  {'context': ' Ты:👀 \n\n Собеседник:🌟 \n\n Ты:Фух, нормальная телега \nА не лагающий nekto me \n\n Собеседник:Я прям удивилась, что ты попросил вк....... \n\n',
#   'response': 'Нууу \nВ телеге я общаюсь больше с очень знакомыми мне людьми \nЯ в ней больше сижу \n'},
#  {'context': ' Собеседник:А у меня наоборот хы \n\n',
#   'response': '🙊 \nЯ уже собирался удалять nekto me \nпочему именоо эта прога ? \nона же ужасная \nкривая \nбе \n'},
#  {'context': ' Собеседник:А у меня наоборот хы \n\n Ты:🙊 \nЯ уже собирался удалять nekto me \nпочему именоо эта прога ? \nона же ужасная \nкривая \nбе \n\n Собеседник:Вот поэтому, когда станешь программистом, напишешь код и все будут счастливы \n\n',
# ...
#   'response': 'Хпххпхп \n'},
#  {'context': ' Собеседник:ладно \nно какая разница \nесли все равно нельзя будет доделать \n\n Ты:Даш \nЧо как тфкп \nБлч я забыл, у тебя же 2 ночи... \n\n Собеседник:ниче \nя не сплю \n\n Ты:Хпххпхп \n\n Собеседник:а делаю тфкп 👎👎👎 \n\n',
#   'response': 'На какой тачке??? \n'},
#  {'context': ' Собеседник:я дошла до 5 задачи \n\n',
#   'response': 'Тачке* \nТаске \nА \nКрутая крутая \n'},
#  {'context': ' Собеседник:я дошла до 5 задачи \n\n Ты:Тачке* \nТаске \nА \nКрутая крутая \n\n Собеседник:чё значит модуль функци \n\n',
#   'response': 'Если что, спрашивай \nМогу подсказать чонить \nСкинь скрин задачи \n'},
#  {'context': ' Собеседник:я дошла до 5 задачи \n\n Ты:Тачке* \nТаске \nА \nКрутая крутая \n\n Собеседник:чё значит модуль функци \n\n Ты:Если что, спрашивай \nМогу подсказать чонить \nСкинь скрин задачи \n\n Собеседник:вот чё нам это даёт \n\n',
#   'response': 'Сча \nНу это корень квадратный из суммы квадратов мнимой и компл чаткй \nВот решение крч \nТам тока с=0 \nПоэтому вбивать без с \n'},
#  {'context': ' Собеседник:окей \nпасиб \nа в ответе же надо f(z) выразить? \n\n',
#   'response': 'yes \n'},
#  {'context': ' Собеседник:окей \nпасиб \nа в ответе же надо f(z) выразить? \n\n Ты:yes \n\n Собеседник:а все \n\n',
#   'response': 'там exp(z^2) \n'},
#  {'context': ' Собеседник:окей \nпасиб \nа в ответе же надо f(z) выразить? \n\n Ты:yes \n\n Собеседник:а все \n\n Ты:там exp(z^2) \n\n Собеседник:да \nя короче \nсегодня ходила гулять с подругой \nи пришла домой часов в 10 \nи тут приходит сообщение что тфкп до полуночи сегодня ))))) \nхорошо что это оказалось не так... \nно я похоже сегодня долго ещё сидеть буду \n\n',
#   'response': 'Жесть \nЯ пошел в бассейн плавать \nИ тут хуякс \nТфкп!! \nБотать!!! \n'},
#  {'context': ' Собеседник:хпххпхпх \nа я ещё коктейльчик выпила... \n\n',
#   'response': 'Пххпхпхпхп \nКайф \n'},
#  {'context': ' Собеседник:хпххпхпх \nа я ещё коктейльчик выпила... \n\n Ты:Пххпхпхпхп \nКайф \n\n Собеседник:у меня монитор выключился \n\n',
#   'response': 'Можно мне тоже коктейлчик, а то эта хрень без него скучно будет решаться \n'},
#  {'context': ' Собеседник:хпххпхпх \nа я ещё коктейльчик выпила... \n\n Ты:Пххпхпхпхп \nКайф \n\n Собеседник:у меня монитор выключился \n\n Ты:Можно мне тоже коктейлчик, а то эта хрень без него скучно будет решаться \n\n Собеседник:он не хочет тфкп показывать \nвыпей \nс ним будет лучше \n\n',
#   'response': 'Все бегу за водкой \n'},
#  {'context': ' Собеседник:а уже поздно .... \n\n',
#   'response': 'Тока так ща тфкп зарешается \nНу и ладно \nЧай так чай \nХоть чифир сделаю \n'},
#  {'context': ' Собеседник:кофе \nчтобы всю ночь делать тфкп 😍 \n\n',
#   'response': 'Привет) \nЧо как тфкп идет)? \n'},
#  {'context': ' Собеседник:кофе \nчтобы всю ночь делать тфкп 😍 \n\n Ты:Привет) \nЧо как тфкп идет)? \n\n Собеседник:привет \nпхпхпх \nя сделала до 7 задачи \nи пошла спать \nи только недавно проснулась \n\n',
#   'response': '😊 \nты кст 6-ое сделала? \nесли да, кинь решение 👉🏻👈🏻👉🏻👈🏻 \n'},
#  {'context': ' Собеседник:я 2 пункт на рандомн сделала \nон уебищный какой то \nа ты вообще до какой задачи дошел?? \n\n',
#   'response': 'до 10-ой \n'},
#  {'context': ' Собеседник:я 2 пункт на рандомн сделала \nон уебищный какой то \nа ты вообще до какой задачи дошел?? \n\n Ты:до 10-ой \n\n Собеседник:а можешь 9 скинуть 👉👈 \nвообще идей нет \n\n',
#   'response': 'сча \n'},
#  {'context': ' Собеседник:я 2 пункт на рандомн сделала \nон уебищный какой то \nа ты вообще до какой задачи дошел?? \n\n Ты:до 10-ой \n\n Собеседник:а можешь 9 скинуть 👉👈 \nвообще идей нет \n\n Ты:сча \n\n Собеседник:пасиб \nа что такое альа н? \nчто вообще в самом конце произошло? \n\n',
#   'response': 'n-ый коэфф последовательности \nпроизведения сумм \n'},
#  {'context': ' Собеседник:так мы же его на z^n+1 поделили ... \n\n',
#   'response': 'так коэфф останутся \nтак Миша делал \n'},
#  {'context': ' Собеседник:а 2пиi это просто интеграл? \n\n',
#   'response': 'yes \nпо окр \nон не зависит от радиуса \nДаш \nТы на каком номере? \nхочешь добавлю тебя в чатик совместного решения домашки)))? \n'},
#  {'context': ' Собеседник:а 2пиi это просто интеграл? \n\n Ты:yes \nпо окр \nон не зависит от радиуса \nДаш \nТы на каком номере? \nхочешь добавлю тебя в чатик совместного решения домашки)))? \n\n Собеседник:да \n\n',
#   'response': 'окес \n'},
#  {'context': ' Собеседник:тока я сама ниче не решила \n\n',
#   'response': 'Даш чо как? \nНа какой задаче? \n'},
#  {'context': ' Собеседник:тока я сама ниче не решила \n\n Ты:Даш чо как? \nНа какой задаче? \n\n Собеседник:бля \nя пила пиво \n\n',
#   'response': 'Хпхпхпхпххп \nНормас я считаю \n'},
#  {'context': ' Собеседник:тока я сама ниче не решила \n\n Ты:Даш чо как? \nНа какой задаче? \n\n Собеседник:бля \nя пила пиво \n\n Ты:Хпхпхпхпххп \nНормас я считаю \n\n Собеседник:щас я доделаю 1 дз \nво 2 потыкаюсь \n\n',
#   'response': 'Кек \nЯ сказал, что не в мск \nИ попросился онлайн \n'},
#  {'context': ' Собеседник:а зачем \nты же в мск \n\n',
#   'response': 'Лень ехать \n'},
#  {'context': ' Собеседник:а зачем \nты же в мск \n\n Ты:Лень ехать \n\n Собеседник:хаххпхпхпхпх \n\n',
#   'response': 'Ну типо, мне дома удобнее сдавать \nПодготовлюсь норм \n'},
#  {'context': ' Собеседник:надо знать содержание теорем.... \nблин я так надеюсь что у нашей группы легко пройдет сдача \n\n',
#   'response': 'Даш \nты тут? \nкак прогресс? \n'},
#  {'context': ' Собеседник:надо знать содержание теорем.... \nблин я так надеюсь что у нашей группы легко пройдет сдача \n\n Ты:Даш \nты тут? \nкак прогресс? \n\n Собеседник:я тут \n\n',
#   'response': 'на какой ты заачеее \n'},
#  {'context': ' Собеседник:надо знать содержание теорем.... \nблин я так надеюсь что у нашей группы легко пройдет сдача \n\n Ты:Даш \nты тут? \nкак прогресс? \n\n Собеседник:я тут \n\n Ты:на какой ты заачеее \n\n Собеседник:но я ниче не делаю \nостановилась на 3ей \nзавтра дорешаю \n\n',
#   'response': 'я вот тока первую во втором разделе начал делать)) \nнормас \nнормас \nа теперь можно и сериалчик бахнуть \n'},
#  {'context': ' Собеседник:у меня она неправильная а там только 1 попытка 😃👍👍 \n\n',
#   'response': 'кайф \n'},
#  {'context': ' Собеседник:у меня она неправильная а там только 1 попытка 😃👍👍 \n\n Ты:кайф \n\n Собеседник:я в генш играла... \n\n',
#   'response': 'я второй акк сделал для этого)) \n'},
#  {'context': ' Собеседник:у меня она неправильная а там только 1 попытка 😃👍👍 \n\n Ты:кайф \n\n Собеседник:я в генш играла... \n\n Ты:я второй акк сделал для этого)) \n\n Собеседник:пхпхпхпхаззпз \nда я тоже думала \nно решила похуй \n\n',
#   'response': 'надеюсь злой британец не вычислит по ip \n'},
#  {'context': ' Собеседник:подумаешь 1 задача неверная \n\n',
#   'response': 'а то он итак на меня злой \nпо факту \nрешила все задачи за исключением множества меры нуль \n'},
#  {'context': ' Собеседник:подумаешь 1 задача неверная \n\n Ты:а то он итак на меня злой \nпо факту \nрешила все задачи за исключением множества меры нуль \n\n Собеседник:а ты вообще не хочешь появляться в здании ниу вшэ?) \n\n',
#   'response': 'зочем)) \n'},
#  {'context': ' Собеседник:тоже так считаю \n\n',
#   'response': 'я буду РАБотать \n'},
#  {'context': ' Собеседник:тоже так считаю \n\n Ты:я буду РАБотать \n\n Собеседник:ты устроился куда то? \n\n',
#   'response': 'Ну типо, я прошёл все собесы, и на этапе, когда меня должны принять все застряло, так как я на 2-ом курсе)) \n'},
#  {'context': ' Собеседник:почему.... \nне берут студентов?? \n\n',
#   'response': 'Крч там отдел кадров говорит, что компания принимает ток с 4-го курса \n'},
#  {'context': ' Собеседник:почему.... \nне берут студентов?? \n\n Ты:Крч там отдел кадров говорит, что компания принимает ток с 4-го курса \n\n Собеседник:мммм заебись \n\n',
#   'response': 'Ну там разбираются сейчас)) \nВот крч))) \n'},
#  {'context': ' Собеседник:почему.... \nне берут студентов?? \n\n Ты:Крч там отдел кадров говорит, что компания принимает ток с 4-го курса \n\n Собеседник:мммм заебись \n\n Ты:Ну там разбираются сейчас)) \nВот крч))) \n\n Собеседник:да уж \nнадеюсь решится \n\n',
#   'response': 'Да похуй \nНайду место если что))) \n'},
#  {'context': ' Собеседник:опять 3 часа ночи....... \n\n',
#   'response': 'Пиздец, у тебя коллок в 14:30.... \nЖесть так жить \n'},
#  {'context': ' Собеседник:опять 3 часа ночи....... \n\n Ты:Пиздец, у тебя коллок в 14:30.... \nЖесть так жить \n\n Собеседник:каво \n\n',
#   'response': 'Зато на 2 часа впереди \n'},
#  {'context': ' Собеседник:опять 3 часа ночи....... \n\n Ты:Пиздец, у тебя коллок в 14:30.... \nЖесть так жить \n\n Собеседник:каво \n\n Ты:Зато на 2 часа впереди \n\n Собеседник:не туда считаешь \n\n',
#   'response': 'Дп \nДа \nТочнее \n'},
#  {'context': ' Собеседник:опять 3 часа ночи....... \n\n Ты:Пиздец, у тебя коллок в 14:30.... \nЖесть так жить \n\n Собеседник:каво \n\n Ты:Зато на 2 часа впереди \n\n Собеседник:не туда считаешь \n\n Ты:Дп \nДа \nТочнее \n\n Собеседник:он в 8 \n\n',
#   'response': 'А \nНу ок \nДа \n🤪 \n'},
#  {'context': ' Собеседник:у нас вообще ток с 17 начинают принимать \n\n',
#   'response': 'Кайф \n'},
#  {'context': ' Собеседник:у нас вообще ток с 17 начинают принимать \n\n Ты:Кайф \n\n Собеседник:мне завтра ещё вещи собирать чтобы лететь((((( \n\n',
#   'response': 'а когда ты возвращаешься? \n'},
#  {'context': ' Собеседник:у нас вообще ток с 17 начинают принимать \n\n Ты:Кайф \n\n Собеседник:мне завтра ещё вещи собирать чтобы лететь((((( \n\n Ты:а когда ты возвращаешься? \n\n Собеседник:в сб \n\n',
#   'response': 'Крутая \nНаконец-то в нормальный город \n'},
#  {'context': ' Собеседник:екб крутой город так то !!!!! \n\n',
#   'response': 'Да ладно, екб топ) \nУ меня там друг!! \nРаботает \nОфициантом!! \n'},
#  {'context': ' Собеседник:хазпзпхахазах \nединственные перспективы в екб... \nкхм \nточнее крутой перспективный город \nкак успехи у тебя \n\n',
#   'response': 'теорему о вычетах изучаю)) \n'},
#  {'context': ' Собеседник:хазпзпхахазах \nединственные перспективы в екб... \nкхм \nточнее крутой перспективный город \nкак успехи у тебя \n\n Ты:теорему о вычетах изучаю)) \n\n Собеседник:я вот нтухя понять не могу))) \n\n',
#   'response': 'крч я на 4-ой \nзадаче \nа ты? \n'},
#  {'context': ' Собеседник:я тож \n\n', 'response': 'нормас \n'},
#  {'context': ' Собеседник:я тож \n\n Ты:нормас \n\n Собеседник:вщ не понимаю как делать ее \n\n',
#   'response': 'чек \nтам про вычеты по фасту \n'},
#  {'context': ' Собеседник:я тож \n\n Ты:нормас \n\n Собеседник:вщ не понимаю как делать ее \n\n Ты:чек \nтам про вычеты по фасту \n\n Собеседник:тип нужно просто вычет посчитать \n\n',
#   'response': 'да \n'},
#  {'context': ' Собеседник:я тож \n\n Ты:нормас \n\n Собеседник:вщ не понимаю как делать ее \n\n Ты:чек \nтам про вычеты по фасту \n\n Собеседник:тип нужно просто вычет посчитать \n\n Ты:да \n\n Собеседник:у меня не особо выходит \nладно щас потыкаюсь \n\n',
#   'response': 'сча я попробую \nсначала примеры все просмотрю \nдаашш \nты на каком? \n'},
#  {'context': ' Собеседник:на 7 \n\n', 'response': 'хера \n'},
#  {'context': ' Собеседник:на 7 \n\n Ты:хера \n\n Собеседник:но я немного скипнула \n\n',
#   'response': 'чо так быстроо \n'},
#  {'context': ' Собеседник:на 7 \n\n Ты:хера \n\n Собеседник:но я немного скипнула \n\n Ты:чо так быстроо \n\n Собеседник:где есть ответы \nчтобы потом написать решение \n\n',
#   'response': 'скинь ответы))) \n'},
#  {'context': ' Собеседник:на 7 \n\n Ты:хера \n\n Собеседник:но я немного скипнула \n\n Ты:чо так быстроо \n\n Собеседник:где есть ответы \nчтобы потом написать решение \n\n Ты:скинь ответы))) \n\n Собеседник:5 есть в беседе \n7 хз пока \n\n',
#   'response': 'а там \nв 5-ом \nкрч, какие ответы на пункт 1, 2 в 5-ом \nя его сейачс считаю, но надо сверить) \nелси тебе не долго чекать их \nжоско \n'},
#  {'context': ' Собеседник:1 пункт у меня нет решения \nответа \n\n',
#   'response': 'даашш \nскинь 7-го решениееее \n'},
#  {'context': ' Собеседник:1 пункт у меня нет решения \nответа \n\n Ты:даашш \nскинь 7-го решениееее \n\n Собеседник:оно кривое оч \n\n',
#   'response': 'пофег \n'},
#  {'context': ' Собеседник:1 пункт у меня нет решения \nответа \n\n Ты:даашш \nскинь 7-го решениееее \n\n Собеседник:оно кривое оч \n\n Ты:пофег \n\n Собеседник:ток там вроде минуса нет \n\n',
#   'response': 'спасибоо \nа ты на каком \nсчас? \n'},
#  {'context': ' Собеседник:1 пункт у меня нет решения \nответа \n\n Ты:даашш \nскинь 7-го решениееее \n\n Собеседник:оно кривое оч \n\n Ты:пофег \n\n Собеседник:ток там вроде минуса нет \n\n Ты:спасибоо \nа ты на каком \nсчас? \n\n Собеседник:на 8 \n\n',
#   'response': 'логично)) \nя тупой соре \n'},
#  {'context': ' Собеседник:хахпххпхп \n\n', 'response': 'даш \nесть \n'},
#  {'context': ' Собеседник:хахпххпхп \n\n Ты:даш \nесть \n\n Собеседник:оо оо \nпасиба \nты просто по всем людям собрал?))) \n\n',
#   'response': 'да)) \nконструктор лего \nсобери свою домашку \n'},
#  {'context': ' Собеседник:хахпххпхп \n\n Ты:даш \nесть \n\n Собеседник:оо оо \nпасиба \nты просто по всем людям собрал?))) \n\n Ты:да)) \nконструктор лего \nсобери свою домашку \n\n Собеседник:а какой ответ то \n\n',
#   'response': 'сча \nузнаемс \nсинус 1 \nкакой тут ответ в итоге? \nа у тебя получилось в 9-ом ответ вбить? \n'},
#  {'context': ' Собеседник:да \n\n', 'response': 'имба \n'},
#  {'context': ' Собеседник:да \n\n Ты:имба \n\n Собеседник:вот бы сразу так)))) \n\n',
#   'response': 'так да \n'},
#  {'context': ' Собеседник:да \n\n Ты:имба \n\n Собеседник:вот бы сразу так)))) \n\n Ты:так да \n\n Собеседник:итак \nвсе ответы есть \nосталось успеть написать решения.... \n\n',
#   'response': 'прикол в том \nчто я не писал вообще ренешия первой части \nточнее я писал \nв разных тетрадках))) \nладно, похуй \nработаем \n'},
#  {'context': ' Собеседник:а ты не знаешь \nтам будет доступ к задачам \nпосле дедлацна \n\n',
#   'response': 'хз \n'},
#  {'context': ' Собеседник:а ты не знаешь \nтам будет доступ к задачам \nпосле дедлацна \n\n Ты:хз \n\n Собеседник:эх \n\n',
#   'response': 'даш \nа скинь полность 7-ой \nкак ты делала \n'},
#  {'context': ' Собеседник:а ты не знаешь \nтам будет доступ к задачам \nпосле дедлацна \n\n Ты:хз \n\n Собеседник:эх \n\n Ты:даш \nа скинь полность 7-ой \nкак ты делала \n\n Собеседник:ща \n\n',
#   'response': 'что да \nскинь))) \nскрин \nтот который кидала не полный) \n'},
#  {'context': ' Собеседник:смысли \nтак \nэто полный был \n\n',
#   'response': 'разве там написан ответ конечный \n'},
#  {'context': ' Собеседник:смысли \nтак \nэто полный был \n\n Ты:разве там написан ответ конечный \n\n Собеседник:1 строчка \n\n',
#   'response': 'ладно, пон \n'},
#  {'context': ' Собеседник:смысли \nтак \nэто полный был \n\n Ты:разве там написан ответ конечный \n\n Собеседник:1 строчка \n\n Ты:ладно, пон \n\n Собеседник:там 2 интеграла \n\n',
#   'response': 'оке \n'},
#  {'context': ' Собеседник:смысли \nтак \nэто полный был \n\n Ты:разве там написан ответ конечный \n\n Собеседник:1 строчка \n\n Ты:ладно, пон \n\n Собеседник:там 2 интеграла \n\n Ты:оке \n\n Собеседник:потом их по отдельности считаю \nи складываю \n\n',
#   'response': 'гуд \nнапишешь, как сдашь) \nудачи! \n'},
#  {'context': ' Собеседник:ещё час !!! \n\n',
#   'response': 'хаха \nнорм \nнорм \nты успела? \nпереписать? \n'},
#  {'context': ' Собеседник:ещё час !!! \n\n Ты:хаха \nнорм \nнорм \nты успела? \nпереписать? \n\n Собеседник:ты вечером сдаешь? \nнет ещё \n\n',
#   'response': 'типо того \n'},
#  {'context': ' Собеседник:ещё час !!! \n\n Ты:хаха \nнорм \nнорм \nты успела? \nпереписать? \n\n Собеседник:ты вечером сдаешь? \nнет ещё \n\n Ты:типо того \n\n Собеседник:я все ответы забила \n\n',
#   'response': 'жээсть ты \n'},
#  {'context': ' Собеседник:ещё час !!! \n\n Ты:хаха \nнорм \nнорм \nты успела? \nпереписать? \n\n Собеседник:ты вечером сдаешь? \nнет ещё \n\n Ты:типо того \n\n Собеседник:я все ответы забила \n\n Ты:жээсть ты \n\n Собеседник:но решения я блин не понимаю \n\n',
#   'response': 'да норм \nскажешь, все очев \nотл 10 \n'},
#  {'context': ' Собеседник:хахахаха \nпочему? - по теореме. \n\n',
#   'response': 'ДАшшш \nа скинь ссылку на эту штуку \nспасибо \n'},
#  ...]

# %%
with open('./all_dialogues.json', 'w', encoding = 'utf8') as json_file:
    json.dump(all_dialogues, json_file, indent=4, ensure_ascii=False)
